# %% [markdown]
# # Lab 10 - Textual Data Analytics
# Complete the code with TODO tag.
# ## 1. Feature Engineering
# In this exercise we will understand the functioning of TF/IDF ranking. Implement the feature engineering and its application, based on the code framework provided below.
#
# First we use textual data from Twitter.

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('elonmusk_tweets.csv')
print(len(data))
data.head()
# Out:
# 2819
#                    id           created_at  \
# 0  849636868052275200  2017-04-05 14:56:29
# 1  848988730585096192  2017-04-03 20:01:01
# 2  848943072423497728  2017-04-03 16:59:35
# 3  848935705057280001  2017-04-03 16:30:19
# 4  848416049573658624  2017-04-02 06:05:23
#
#                                                 text
# 0  b'And so the robots spared humanity ... https:...
# 1  b"@ForIn2020 @waltmossberg @mims @defcon_5 Exa...
# 2      b'@waltmossberg @mims @defcon_5 Et tu, Walt?'
# 3                b'Stormy weather in Shortville ...'
# 4  b"@DaveLeeBBC @verge Coal is dying due to nat ...

# %% [markdown]
# ### 1.1. Text Normalization
# Now we need to normalize text by stemming, tokenizing, and removing stopwords.

# %%
from __future__ import print_function, division
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
nltk.download('punkt')
import string
from nltk.corpus import stopwords
import math
from collections import Counter
nltk.download('stopwords')
import pprint 
pp = pprint.PrettyPrinter(indent=4)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Duy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Duy\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def normalize(document):
    # TODO: remove punctuation
    #s.translate(None, string.punctuation)
    text = document
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    for x in document.lower():
        if x in punctuations:
             text = text.replace(x, "") 
    
    # tokenize text
    tokens = nltk.word_tokenize(text)
    
    # Stemming
    stemmer = PorterStemmer()
    ret = " ".join([stemmer.stem(word.lower()) for word in tokens])
    return ret

original_documents = [x.strip() for x in data['text']] 
documents = [normalize(d).split() for d in original_documents]
documents[0]
# Out:
# ['band', 'so', 'the', 'robot', 'spare', 'human', 'httpstcov7jujqwfcv']

# %% [markdown]
# As you can see that the normalization is still not perfect. Please feel free to improve upon (OPTIONAL), e.g. https://marcobonzanini.com/2015/03/09/mining-twitter-data-with-python-part-2/

# %% [markdown]
# ### 1.2. Implement TF-IDF
# Now you need to implement TF-IDF, including creating the vocabulary, computing term frequency, and normalizing by tf-idf weights.

# %%
# Flatten all the documents
flat_list = [word for doc in documents for word in doc]

# TODO: remove stop words from the vocabulary
words = []
stop_words = set(stopwords.words('english'))
for x in flat_list:
    if x not in stop_words:
        words.append(x)

# we take the 500 most common words only
counts = Counter(words)
vocabulary = counts.most_common(500)
print([x for x in vocabulary if x[0] == 'tesla'])
vocabulary = [x[0] for x in vocabulary]
assert len(vocabulary) == 500

# vocabulary.sort()
vocabulary[:5]
# Out:
# [('tesla', 287)]
# ['brt', 'tesla', 'spacex', 'model', 'thi']

# %%
def tf(vocabulary, documents):
    matrix = [0] * len(documents)
    for i, document in enumerate(documents):
        counts = Counter(document)
        matrix[i] = [0] * len(vocabulary)
        for j, term in enumerate(vocabulary):
            matrix[i][j] = counts[term]
    return matrix

tf = tf(vocabulary, documents)
np.array(vocabulary)[np.where(np.array(tf[1]) > 0)], np.array(tf[1])[np.where(np.array(tf[1]) > 0)]
# Out:
# (array(['tesla', 'exactli'], dtype='<U17'), array([1, 1]))

# %%
vocabulary
# Out:
# ['brt',
#  'tesla',
#  'spacex',
#  'model',
#  'thi',
#  'amp',
#  'car',
#  'teslamotor',
#  'launch',
#  'like',
#  'rocket',
#  'wa',
#  'good',
#  'land',
#  'dragon',
#  'ye',
#  'need',
#  'time',
#  'falcon',
#  'test',
#  'make',
#  'next',
#  'year',
#  'ha',
#  'first',
#  'go',
#  'thank',
#  'look',
#  'elonmusk',
#  'new',
#  'work',
#  '3',
#  'one',
#  'week',
#  'would',
#  '9',
#  'x',
#  'peopl',
#  'space',
#  'get',
#  'great',
#  'autopilot',
#  'use',
#  'mar',
#  'flight',
#  'drive',
#  'w',
#  'nasa',
#  'day',
#  'btesla',
#  'onli',
#  'much',
#  'best',
#  'engin',
#  'come',
#  'today',
#  'also',
#  'product',
#  'lot',
#  'realli',
#  'solar',
#  'mile',
#  'us',
#  'love',
#  'way',
#  'right',
#  'stage',
#  'system',
#  'live',
#  'back',
#  'think',
#  'chang',
#  'take',
#  'dont',
#  'articl',
#  'better',
#  'orbit',
#  '2',
#  'hope',
#  'actual',
#  'soon',
#  'world',
#  'probabl',
#  'fire',
#  'high',
#  'ever',
#  'power',
#  'futur',
#  'mission',
#  'show',
#  'still',
#  'im',
#  'say',
#  'station',
#  'team',
#  'video',
#  'human',
#  'open',
#  'bmodel',
#  'read',
#  'mani',
#  'batteri',
#  'want',
#  'point',
#  'mayb',
#  'updat',
#  'yeah',
#  'see',
#  'tri',
#  'watch',
#  'month',
#  'softwar',
#  'ai',
#  'start',
#  'veri',
#  'last',
#  'ani',
#  'owner',
#  'supercharg',
#  'climat',
#  'thing',
#  'order',
#  'improv',
#  'long',
#  'end',
#  'well',
#  '5',
#  'know',
#  'bjust',
#  'electr',
#  'tomorrow',
#  'awesom',
#  'help',
#  'deploy',
#  'could',
#  'energi',
#  'satellit',
#  'hyperloop',
#  'via',
#  'exactli',
#  'due',
#  '1',
#  'cape',
#  'target',
#  'whi',
#  'bthe',
#  'vehicl',
#  'call',
#  'true',
#  'almost',
#  'sure',
#  'even',
#  'hi',
#  'complet',
#  'la',
#  'et',
#  'design',
#  'happen',
#  'support',
#  'cool',
#  'unveil',
#  'full',
#  'advanc',
#  'someth',
#  'appreci',
#  'announc',
#  'canaver',
#  'befor',
#  'life',
#  'thrust',
#  'alreadi',
#  'cours',
#  'plan',
#  'ship',
#  'tax',
#  'min',
#  'compani',
#  'hour',
#  'speed',
#  'done',
#  'kid',
#  'review',
#  'may',
#  'super',
#  'made',
#  'california',
#  'weather',
#  'releas',
#  'alway',
#  'charg',
#  'earth',
#  'air',
#  'attempt',
#  'big',
#  'droneship',
#  'real',
#  '1st',
#  'heavi',
#  'httpsxe2x80xa6',
#  'allow',
#  'build',
#  'custom',
#  'post',
#  'person',
#  'servic',
#  'hard',
#  'rate',
#  'gener',
#  'v',
#  'leg',
#  'ga',
#  'import',
#  'bfalcon',
#  'low',
#  '6',
#  'pad',
#  'rang',
#  'motor',
#  'vs',
#  'stori',
#  'enough',
#  'sec',
#  'safeti',
#  'trip',
#  'wont',
#  'cant',
#  'turn',
#  'upper',
#  'success',
#  'piec',
#  'version',
#  'happi',
#  'side',
#  'less',
#  'caus',
#  'give',
#  'price',
#  'close',
#  'sound',
#  'spacest',
#  'record',
#  'agre',
#  'second',
#  'thought',
#  'later',
#  'part',
#  'hold',
#  'seem',
#  'matter',
#  'creat',
#  'httpstcoxe2x80xa6',
#  'center',
#  'moon',
#  'risk',
#  'ok',
#  'elon',
#  'detail',
#  'didnt',
#  'home',
#  'cover',
#  'perform',
#  'mph',
#  'sever',
#  'doe',
#  'state',
#  'data',
#  'report',
#  'road',
#  'night',
#  'bwill',
#  'max',
#  'dealer',
#  'upgrad',
#  'achiev',
#  '60',
#  'around',
#  'countri',
#  'pack',
#  'ask',
#  'bam',
#  'bit',
#  'spaceship',
#  'doesnt',
#  'isnt',
#  'never',
#  'tweet',
#  'control',
#  'move',
#  'feel',
#  'said',
#  'find',
#  'camera',
#  'far',
#  'earli',
#  'top',
#  'recommend',
#  'return',
#  'news',
#  'name',
#  'booster',
#  'littl',
#  'photo',
#  'vertic',
#  'bif',
#  '4',
#  'amaz',
#  'took',
#  'definit',
#  'technolog',
#  'cost',
#  'fix',
#  'issu',
#  'hear',
#  'pleas',
#  'carbon',
#  'set',
#  'possibl',
#  'action',
#  'wrong',
#  'meet',
#  'everi',
#  'roof',
#  'rear',
#  'bgood',
#  'head',
#  'blaunch',
#  'texa',
#  'believ',
#  'option',
#  'problem',
#  'fast',
#  'consum',
#  'mean',
#  'confirm',
#  '10',
#  '+',
#  'free',
#  'bspacex',
#  'without',
#  'might',
#  'two',
#  'spacecraft',
#  'roll',
#  'fli',
#  'small',
#  'anyth',
#  'wire',
#  'bad',
#  'track',
#  'tonight',
#  'expect',
#  'goe',
#  'must',
#  'deliv',
#  'got',
#  'ride',
#  'xe2x80xa6',
#  'short',
#  'sale',
#  'public',
#  'coast',
#  'pass',
#  'openai',
#  'bring',
#  'fulli',
#  'minut',
#  'window',
#  'three',
#  'yet',
#  'care',
#  'ive',
#  'talk',
#  'line',
#  'complex',
#  'total',
#  'save',
#  'sens',
#  'direct',
#  'idea',
#  'gigafactori',
#  'weekend',
#  'morn',
#  'stop',
#  'critic',
#  'pod',
#  'musk',
#  'water',
#  'increas',
#  'bvicent',
#  '14',
#  'bidaacarmack',
#  'solarc',
#  'interest',
#  'bgreat',
#  'size',
#  'auto',
#  'door',
#  'physic',
#  'extrem',
#  'question',
#  'worth',
#  'china',
#  'away',
#  'limit',
#  'hit',
#  'machin',
#  'reason',
#  'play',
#  'place',
#  'level',
#  '100',
#  'case',
#  'abort',
#  'fair',
#  'break',
#  'mention',
#  'forc',
#  'tmrw',
#  'radar',
#  'bi',
#  'seat',
#  'veloc',
#  'death',
#  'bmi',
#  'oper',
#  'bwe',
#  'reentri',
#  'brocket',
#  'httptcoxe2x80xa6',
#  'thruster',
#  'develop',
#  'crazi',
#  'def',
#  'ad',
#  'deep',
#  'learn',
#  'though',
#  'keep',
#  'seri',
#  'featur',
#  'game',
#  'number',
#  'hous',
#  'burn',
#  'check',
#  'term',
#  'pressur',
#  'provid',
#  'anoth',
#  'beauti',
#  'law',
#  'job',
#  'requir',
#  'webcast',
#  'belonmusk',
#  '30',
#  'media',
#  'view',
#  'reach',
#  'experi',
#  'suggest',
#  'bdragon',
#  'ocean',
#  'babout',
#  'entir',
#  '20',
#  'mode',
#  'current',
#  'travel',
#  'research',
#  'norway',
#  'white',
#  'wish',
#  'hardwar',
#  'selfdriv',
#  'forward',
#  'welcom',
#  'liftoff',
#  'note',
#  'excit',
#  'bthank',
#  'chanc',
#  'fuel',
#  'bbtw',
#  'fine',
#  'blook',
#  'publish',
#  'million',
#  'readi',
#  'heard',
#  'ft',
#  'rais',
#  'race',
#  'taken',
#  'buy',
#  'wind',
#  'favor',
#  'clear',
#  'store',
#  'includ']

# %%
documents
# Out:
# [['band', 'so', 'the', 'robot', 'spare', 'human', 'httpstcov7jujqwfcv'],
#  ['bforin2020',
#   'waltmossberg',
#   'mim',
#   'defcon5',
#   'exactli',
#   'tesla',
#   'is',
#   'absurdli',
#   'overvalu',
#   'if',
#   'base',
#   'on',
#   'the',
#   'past',
#   'but',
#   'that',
#   'irrxe2x80xa6',
#   'httpstcoqqctqkzgml'],
#  ['bwaltmossberg', 'mim', 'defcon5', 'et', 'tu', 'walt'],
#  ['bstormi', 'weather', 'in', 'shortvil'],
#  ['bdaveleebbc',
#   'verg',
#   'coal',
#   'is',
#   'die',
#   'due',
#   'to',
#   'nat',
#   'ga',
#   'frack',
#   'it',
#   'basic',
#   'dead'],
#  ['blexxxzi', 'it', 'just', 'a', 'helicopt', 'in', 'helicopt', 'cloth'],
#  ['bverg', 'it', 'wont', 'matter'],
#  ['bsupercoolcub', 'pretti', 'good'],
#  ['bwhi',
#   'did',
#   'we',
#   'wast',
#   'so',
#   'much',
#   'time',
#   'develop',
#   'silli',
#   'rocket',
#   'damn',
#   'you',
#   'alien',
#   'so',
#   'obtus',
#   'you',
#   'have',
#   'all',
#   'thi',
#   'crazi',
#   'tech',
#   'but',
#   'cant',
#   'speak',
#   'english'],
#  ['btechnolog',
#   'breakthrough',
#   'turn',
#   'out',
#   'chemtrail',
#   'are',
#   'actual',
#   'a',
#   'messag',
#   'from',
#   'timetravel',
#   'alien',
#   'describ',
#   'the',
#   'secret',
#   'of',
#   'teleport'],
#  ['brt',
#   'openai',
#   'weve',
#   'creat',
#   'the',
#   'world',
#   'first',
#   'spamdetect',
#   'ai',
#   'train',
#   'entir',
#   'in',
#   'simul',
#   'and',
#   'deploy',
#   'on',
#   'a',
#   'physic',
#   'robot',
#   'httpstcoxe2x80xa6'],
#  ['brt',
#   'profbriancox',
#   'thi',
#   'is',
#   'extrem',
#   'import',
#   'from',
#   'elonmusk',
#   'and',
#   'spacex',
#   'reusabl',
#   'rocket',
#   'bring',
#   'us',
#   'much',
#   'closer',
#   'to',
#   'becom',
#   'a',
#   'spacefaringxe2x80xa6'],
#  ['badamsbj',
#   'def',
#   'p100d',
#   'with',
#   'ludicrous+',
#   'although',
#   'the',
#   'rocket',
#   'start',
#   'go',
#   'a',
#   'lot',
#   'faster',
#   'after',
#   'that'],
#  ['bbadastronom',
#   'we',
#   'can',
#   'def',
#   'bring',
#   'it',
#   'back',
#   'like',
#   'dragon',
#   'just',
#   'a',
#   'question',
#   'of',
#   'how',
#   'much',
#   'weight',
#   'we',
#   'need',
#   'to',
#   'add'],
#  ['bteslaaddict', 'teslamotor', 'work', 'on', 'it'],
#  ['bjasonlamb',
#   'look',
#   'like',
#   'it',
#   'could',
#   'do',
#   '20',
#   'more',
#   'with',
#   'some',
#   'structur',
#   'upgrad',
#   'to',
#   'handl',
#   'higher',
#   'load',
#   'but',
#   'that',
#   'in',
#   'fulli',
#   'expend',
#   'mode'],
#  ['bcheron', 'a', 'lot'],
#  ['bcardoso',
#   'silliest',
#   'thing',
#   'we',
#   'can',
#   'imagin',
#   'secret',
#   'payload',
#   'of',
#   '1st',
#   'dragon',
#   'flight',
#   'wa',
#   'a',
#   'giant',
#   'wheel',
#   'of',
#   'chees',
#   'inspir',
#   'bxe2x80xa6',
#   'httpstco68nmjkipsc'],
#  ['bredletterdav', 'good', 'point', 'odd', 'go', 'from', '0', 'to', 'gt0'],
#  ['bfalcon',
#   'heavi',
#   'test',
#   'flight',
#   'current',
#   'schedul',
#   'for',
#   'late',
#   'summer'],
#  ['bconsid',
#   'tri',
#   'to',
#   'bring',
#   'upper',
#   'stage',
#   'back',
#   'on',
#   'falcon',
#   'heavi',
#   'demo',
#   'flight',
#   'for',
#   'full',
#   'reusabl',
#   'odd',
#   'of',
#   'success',
#   'low',
#   'but',
#   'mayb',
#   'worth',
#   'a',
#   'shot'],
#  ['boxfordteddi',
#   'browser',
#   'is',
#   'alreadi',
#   'a',
#   'littl',
#   'better',
#   'kernel',
#   'and',
#   'browser',
#   'updat',
#   'in',
#   'prob',
#   '6',
#   'week',
#   'or',
#   'so',
#   'lot',
#   'of',
#   'underlyinxe2x80xa6',
#   'httpstcoxtgqgwj21d'],
#  ['brt',
#   'spacex',
#   'more',
#   'photo',
#   'from',
#   'todayxe2x80x99',
#   'falcon',
#   '9',
#   'launch',
#   'and',
#   'first',
#   'stage',
#   'land',
#   'xe2x86x92',
#   'httpstco095whx44bx',
#   'httpstcoc3uyhmrdec'],
#  ['bbadastronom', 'spacex', 'thank', 'phil'],
#  ['bincred',
#   'proud',
#   'of',
#   'the',
#   'spacex',
#   'team',
#   'for',
#   'achiev',
#   'thi',
#   'mileston',
#   'in',
#   'space',
#   'next',
#   'goal',
#   'is',
#   'reflight',
#   'within',
#   '24',
#   'hour'],
#  ['brt',
#   'spacex',
#   'falcon',
#   '9',
#   'first',
#   'stage',
#   'ha',
#   'land',
#   'on',
#   'of',
#   'cours',
#   'i',
#   'still',
#   'love',
#   'you',
#   'xe2x80x94',
#   'worldxe2x80x99',
#   'first',
#   'reflight',
#   'of',
#   'an',
#   'orbit',
#   'class',
#   'rocket'],
#  ['brt',
#   'spacex',
#   '60',
#   'minut',
#   'until',
#   'launch',
#   'window',
#   'for',
#   'ses10',
#   'open',
#   'all',
#   'system',
#   'and',
#   'weather',
#   'are',
#   'go',
#   'watch',
#   'here',
#   'xe2x86x92',
#   'httpstcogtc39ubc7z',
#   'httpsxe2x80xa6'],
#  ['brt',
#   'spacex',
#   'falcon',
#   '9',
#   'and',
#   'ses10',
#   'vertic',
#   'on',
#   'kennedi',
#   'space',
#   'centerxe2x80x99',
#   'histor',
#   'pad',
#   '39a',
#   'launch',
#   'window',
#   'open',
#   'at',
#   '627pm',
#   'edt',
#   '1027pm',
#   'utc',
#   'httpsxe2x80xa6'],
#  ['bmade', 'today', 'on', 'tesla', 'sketch', 'pad', 'httpstcoz8dfp2nn41'],
#  ['bif',
#   'you',
#   'just',
#   'download',
#   'v81',
#   'tap',
#   'the',
#   'the',
#   't',
#   'on',
#   'center',
#   'screen',
#   'three',
#   'time'],
#  ['bdrmanejwala',
#   'arctechinc',
#   'on',
#   'center',
#   'screen',
#   'also',
#   'center',
#   'screen',
#   'will',
#   'show',
#   'speed',
#   'as',
#   'an',
#   'overlay',
#   'that',
#   'chang',
#   'opac',
#   'accord',
#   'to',
#   'relev'],
#  ['bdanahul',
#   'veri',
#   'few',
#   'we',
#   'have',
#   'yet',
#   'to',
#   'do',
#   'a',
#   'china',
#   'or',
#   'europ',
#   'launch',
#   'of',
#   'model',
#   '3'],
#  ['bbusi',
#   'glad',
#   'to',
#   'have',
#   'tencent',
#   'as',
#   'an',
#   'investor',
#   'and',
#   'advisor',
#   'to',
#   'tesla'],
#  ['bnickguk', 'chouky02', 'no'],
#  ['bnickguk', 'chouky02', 'you', 'wont', 'care'],
#  ['bnakatomitim', 'what', 'gave', 'me', 'away'],
#  ['bnickguk', 'no'],
#  ['bhere',
#   'is',
#   'the',
#   'latest',
#   'spacex',
#   'travel',
#   'ad',
#   'for',
#   'the',
#   'flight',
#   'around',
#   'the',
#   'moon',
#   'amp',
#   'into',
#   'deep',
#   'space',
#   'mayb',
#   'need',
#   'a',
#   'few',
#   'edit',
#   'httpstcoma8zgutrb'],
#  ['blong',
#   'neuralink',
#   'piec',
#   'come',
#   'out',
#   'on',
#   'waitbutwhi',
#   'in',
#   'about',
#   'a',
#   'week',
#   'difficult',
#   'to',
#   'dedic',
#   'the',
#   'time',
#   'but',
#   'existenti',
#   'risk',
#   'is',
#   'too',
#   'high',
#   'not',
#   'to'],
#  ['brt',
#   'openai',
#   'new',
#   'research',
#   'releas',
#   'overcom',
#   'mani',
#   'of',
#   'reinforc',
#   'learn',
#   'limit',
#   'with',
#   'evolut',
#   'strategi',
#   'httpstcofvistofd'],
#  ['berikhaaland',
#   'we',
#   'can',
#   'not',
#   'make',
#   'all',
#   'countri',
#   'version',
#   'simultan',
#   'or',
#   'the',
#   'product',
#   'start',
#   'would',
#   'be',
#   'a',
#   'disast',
#   'you',
#   'would',
#   'get',
#   'first',
#   'in',
#   'norway'],
#  ['bisabellek', 'ye'],
#  ['bd1sneynut', 'ye'],
#  ['bnickbaum', 'i', 'believ', 'so'],
#  ['bnddugan', 'yup'],
#  ['bmreweguy', 'oh', 'so', 'littl', 'faith'],
#  ['bkryniog',
#   'the',
#   'shorter',
#   'wheelbas',
#   'onli',
#   'allow',
#   'for',
#   'a',
#   '75',
#   'kwh',
#   'pack',
#   'in',
#   'model',
#   '3',
#   'at',
#   'current',
#   'cellmodul',
#   'energi',
#   'densiti'],
#  ['brt',
#   'pokervixen',
#   'elonmusk',
#   'im',
#   'so',
#   'unbeliev',
#   'happi',
#   'with',
#   'my',
#   'model',
#   's',
#   'when',
#   'peopl',
#   'ask',
#   'if',
#   'l',
#   'like',
#   'it',
#   'i',
#   'respond',
#   'no',
#   'i',
#   'love',
#   'it',
#   'xf0x9fx98x8d',
#   'it',
#   'amazingxe2x80xa6'],
#  ['brt',
#   'rhway',
#   'elonmusk',
#   'our',
#   '85',
#   'hit',
#   'the',
#   'guardrail',
#   'at',
#   'well',
#   'over',
#   '160kmh',
#   'tessi',
#   'absorb',
#   'impact',
#   'wife',
#   'and',
#   'babi',
#   'are',
#   'ok',
#   'best',
#   'car',
#   'ever',
#   'amp',
#   'member',
#   'oxe2x80xa6'],
#  ['btoddgerken', 'yeah'],
#  ['bholsmichael', 'start', 'take', 'order', 'in', 'april'],
#  ['bdrangu',
#   'yeah',
#   'probabl',
#   'a',
#   'year',
#   'from',
#   'now',
#   's',
#   'will',
#   'still',
#   'win',
#   'on',
#   'acceler',
#   'though',
#   'due',
#   'to',
#   'have',
#   'more',
#   'space',
#   'for',
#   'a',
#   'larger',
#   'batteri'],
#  ['brt',
#   'morrisonbrett',
#   'elonmusk',
#   'first',
#   'batch',
#   'model',
#   's',
#   'p85d',
#   'for',
#   'me',
#   'grey',
#   'signatur',
#   'model',
#   'x',
#   'p90d',
#   'for',
#   'wife',
#   'tripl',
#   'white',
#   'best',
#   'vehicl',
#   'in',
#   'the',
#   'worxe2x80xa6'],
#  ['bakawreck',
#   'ckalapala',
#   'onli',
#   'model',
#   's',
#   'will',
#   'have',
#   'the',
#   'seven',
#   'seater',
#   'option',
#   'more',
#   'cargo',
#   'space',
#   'plu',
#   'higher',
#   'rang',
#   'acceleraxe2x80xa6',
#   'httpstco3wucazrkza'],
#  ['brt',
#   'arctechinc',
#   'elonmusk',
#   'we',
#   'believ',
#   'so',
#   'much',
#   'in',
#   'tesla',
#   'and',
#   'it',
#   'goal',
#   'we',
#   'have',
#   'a',
#   '100d',
#   'model',
#   's',
#   'and',
#   '90d',
#   'model',
#   'x',
#   'and',
#   'love',
#   'both',
#   'thank',
#   'you',
#   'httpsxe2x80xa6'],
#  ['bcamkod',
#   'the',
#   'model',
#   's',
#   'produc',
#   'today',
#   'is',
#   'arguabl',
#   'version',
#   '4',
#   'let',
#   'me',
#   'put',
#   'it',
#   'thi',
#   'way',
#   'it',
#   'is',
#   'the',
#   'car',
#   'i',
#   'will',
#   'keep',
#   'drivinxe2x80xa6',
#   'httpstcoxaxvz9txpa'],
#  ['brt',
#   'herifinteki',
#   'elonmusk',
#   'my',
#   'lil',
#   'monster',
#   'tesla',
#   'model',
#   'x',
#   'is',
#   'the',
#   'best',
#   'car',
#   'ive',
#   'ever',
#   'use',
#   'thank',
#   'you',
#   'elon',
#   'xe2x9dxa4xefxb8x8f'],
#  ['bbluebowl',
#   'if',
#   'fate',
#   'is',
#   'on',
#   'our',
#   'side',
#   'it',
#   'will',
#   'be',
#   'amaz',
#   'will',
#   'talk',
#   'about',
#   'that',
#   'in',
#   'detail',
#   'next',
#   'week'],
#  ['bjuanmlemao', 'no', 'problem'],
#  ['bdjburg',
#   'should',
#   'be',
#   'summer',
#   'next',
#   'year',
#   'sorri',
#   'realli',
#   'wish',
#   'we',
#   'could',
#   'get',
#   'rhd',
#   'done',
#   'sooner',
#   'we',
#   'truli',
#   'are',
#   'work',
#   'as',
#   'fast',
#   'as',
#   'we',
#   'can'],
#  ['bfaultywarrior',
#   'matttrulli',
#   'fredericlambert',
#   'timshelton',
#   'jimpengelli',
#   'let',
#   'me',
#   'just',
#   'go',
#   'fetch',
#   'my',
#   'magic',
#   'wand'],
#  ['brt',
#   'ricardotwumasi',
#   'elonmusk',
#   'my',
#   'tesla',
#   'model',
#   's',
#   'is',
#   'the',
#   'best',
#   'car',
#   'ive',
#   'ever',
#   'had',
#   'httpstcoobkdjopruo'],
#  ['brt',
#   'shkottt',
#   'elonmusk',
#   'my',
#   'tesla',
#   'roadster',
#   'is',
#   'the',
#   'best',
#   'car',
#   'ive',
#   'ever',
#   'had'],
#  ['btimshelton',
#   'fredericlambert',
#   'jimpengelli',
#   'first',
#   'in',
#   'line',
#   'for',
#   'dual',
#   'motor',
#   'as',
#   'soon',
#   'as',
#   'we',
#   'can',
#   'make',
#   'it',
#   'which',
#   'is',
#   'probabl',
#   'in',
#   '6',
#   'to',
#   '9',
#   'month'],
#  ['bmeangene2030',
#   'damn',
#   'straight',
#   'we',
#   'do',
#   'come',
#   'with',
#   '81',
#   'next',
#   'week'],
#  ['bfirst',
#   'drive',
#   'of',
#   'a',
#   'releas',
#   'candid',
#   'version',
#   'of',
#   'model',
#   '3',
#   'httpstcozcs6j1yra4'],
#  ['bfredericlambert', 'it', 'still', 'ha', 'one', 'display'],
#  ['brt',
#   'danieltadro',
#   'bobbykansara',
#   'elonmusk',
#   'mrthorman',
#   'my',
#   'model',
#   's',
#   'is',
#   'the',
#   'best',
#   'car',
#   'ive',
#   'ever',
#   'had'],
#  ['bvoltzcoreaudio',
#   'noth',
#   'majorli',
#   'new',
#   'that',
#   'a',
#   'consum',
#   'would',
#   'notic',
#   'lot',
#   'of',
#   'new',
#   'tech',
#   'in',
#   'the',
#   'design',
#   'and',
#   'product',
#   'process',
#   'though'],
#  ['barctechinc',
#   'the',
#   'more',
#   'autonom',
#   'a',
#   'car',
#   'is',
#   'the',
#   'less',
#   'dash',
#   'info',
#   'you',
#   'need',
#   'how',
#   'often',
#   'do',
#   'you',
#   'look',
#   'at',
#   'the',
#   'instrument',
#   'panexe2x80xa6',
#   'httpstcoie6abxs7ld'],
#  ['basimo3089',
#   'how',
#   'about',
#   'the',
#   'video',
#   'we',
#   'just',
#   'took',
#   'of',
#   'the',
#   'first',
#   'model',
#   '3',
#   'releas',
#   'candid',
#   'drive'],
#  ['brt',
#   'bobbykansara',
#   'mrthorman',
#   'elonmusk',
#   'my',
#   'model',
#   'x',
#   'is',
#   'the',
#   'greatest',
#   'thing',
#   'i',
#   'have',
#   'ever',
#   'purchas',
#   'period'],
#  ['btrabru',
#   'yup',
#   'machin',
#   'arriv',
#   'next',
#   'month',
#   'and',
#   'we',
#   'start',
#   'dig',
#   'the',
#   'tunnel'],
#  ['boakhal', 'i', 'think', 'so'],
#  ['bfredericlambert',
#   'jimpengelli',
#   'no',
#   'we',
#   'are',
#   'minim',
#   'configur',
#   'complex',
#   'to',
#   'keep',
#   'the',
#   'product',
#   'ramp',
#   'on',
#   'schedulxe2x80xa6',
#   'httpstcorehqoy149t'],
#  ['btrojan81', 'tuesw'],
#  ['bjdaz',
#   'becaus',
#   'i',
#   'wa',
#   'a',
#   'dumb',
#   'idiot',
#   'and',
#   'didnt',
#   'realiz',
#   'at',
#   'the',
#   'time',
#   'that',
#   'it',
#   'would',
#   'caus',
#   'confus'],
#  ['btimothymjr', 'tuesw', 'next', 'week'],
#  ['bskateabook',
#   'ye',
#   'model',
#   's',
#   'will',
#   'alway',
#   'be',
#   'the',
#   'fastest',
#   'tesla',
#   'until',
#   'next',
#   'gen',
#   'roadster',
#   'which',
#   'is',
#   'a',
#   'few',
#   'year',
#   'away'],
#  ['bjimpengelli', 'ye', 'but', 'not', 'until', 'next', 'year'],
#  ['balsaibi',
#   'ye',
#   'hardwar',
#   'alreadi',
#   'on',
#   'all',
#   'product',
#   's',
#   'and',
#   'x',
#   'car'],
#  ['bthekenmil',
#   'sorta',
#   'model',
#   '3',
#   'is',
#   'like',
#   'a',
#   'bmw',
#   '3',
#   'seri',
#   'or',
#   'audi',
#   'a4',
#   'model',
#   's',
#   'is',
#   'like',
#   'bmw',
#   '5',
#   'and',
#   '6',
#   'seri',
#   'but',
#   'much',
#   'fastexe2x80xa6',
#   'httpstcom7gxmtjgrz'],
#  ['bgreg525', 'how', 'about', 'now'],
#  ['bvarunfatehpuria',
#   'oh',
#   'model',
#   'y',
#   'is',
#   'come',
#   'too',
#   'in',
#   'a',
#   'few',
#   'year',
#   'kinda',
#   'have',
#   'to'],
#  ['bluciojr',
#   'all',
#   'tesla',
#   'car',
#   'built',
#   'sinc',
#   'oct',
#   'last',
#   'year',
#   'will',
#   'be',
#   'capabl',
#   'of',
#   'selfdriv',
#   'as',
#   'softwar',
#   'improv'],
#  ['bswindeez', 'definit'],
#  ['bmodel',
#   '3',
#   'wa',
#   'go',
#   'to',
#   'be',
#   'call',
#   'model',
#   'e',
#   'for',
#   'obviou',
#   'dumb',
#   'humor',
#   'reason',
#   'but',
#   'ford',
#   'su',
#   'to',
#   'block',
#   'it',
#   'so',
#   'now',
#   'it',
#   'is',
#   's3x',
#   'total',
#   'differ'],
#  ['btimbeiko', 'ye'],
#  ['bmodel',
#   '3',
#   'is',
#   'just',
#   'a',
#   'smaller',
#   'more',
#   'afford',
#   'version',
#   'of',
#   'model',
#   's',
#   'w',
#   'less',
#   'rang',
#   'amp',
#   'power',
#   'amp',
#   'fewer',
#   'featur',
#   'model',
#   's',
#   'ha',
#   'more',
#   'advanc',
#   'technolog'],
#  ['bam',
#   'notic',
#   'that',
#   'mani',
#   'peopl',
#   'think',
#   'model',
#   '3',
#   'is',
#   'the',
#   'next',
#   'version',
#   'of',
#   'a',
#   'tesla',
#   'like',
#   'iphon',
#   '2',
#   'vs',
#   '3',
#   'thi',
#   'is',
#   'not',
#   'true'],
#  ['bmacwaltersl',
#   'look',
#   'forward',
#   'to',
#   'play',
#   'the',
#   'game',
#   'with',
#   'my',
#   'kid'],
#  ['baaronpaul8',
#   'i',
#   'use',
#   'to',
#   'be',
#   'one',
#   'your',
#   'welcom',
#   'tri',
#   'my',
#   'best',
#   'at',
#   'least',
#   'hope',
#   'it',
#   'a',
#   'bit',
#   'use'],
#  ['bnextspaceflight',
#   'inversedotcom',
#   'just',
#   'becaus',
#   'im',
#   'build',
#   'a',
#   'spaceship',
#   'to',
#   'get',
#   'back',
#   'to',
#   'my',
#   'home',
#   'planet',
#   'doesnt',
#   'mean',
#   'im',
#   'an',
#   'alien'],
#  ['blennart375',
#   'inversedotcom',
#   'the',
#   'number',
#   'of',
#   'extinct',
#   'singl',
#   'planet',
#   'civil',
#   'probabl',
#   'exce',
#   'live',
#   'civ',
#   'by',
#   'at',
#   'leastxe2x80xa6',
#   'httpstco7rzdepnok'],
#  ['bphirat',
#   'probabl',
#   'either',
#   'that',
#   'simul',
#   'great',
#   'filter',
#   'or',
#   'they',
#   'are',
#   'veri',
#   'veri',
#   'subtl'],
#  ['bnite', 'i', 'hope', 'that', 'didnt', 'work'],
#  ['bnite', 'spawn', 'npcalien'],
#  ['bwhere', 'are', 'the', 'gt', 'alien', 'httpstcofdujidwgrn'],
#  ['bwouterhuij', 'look', 'like', 'tuesw', 'for', '81', 'releas'],
#  ['bx17onlin', 'except', 'that', 'isnt', 'actual', 'my', 'hous'],
#  ['bkaraswish',
#   'perhap',
#   'there',
#   'will',
#   'be',
#   'some',
#   'futur',
#   'bill',
#   'that',
#   'make',
#   'a',
#   'differ',
#   'for',
#   'mar',
#   'but',
#   'thi',
#   'is',
#   'not',
#   'it'],
#  ['bkaraswish',
#   'i',
#   'am',
#   'not',
#   'thi',
#   'bill',
#   'chang',
#   'almost',
#   'noth',
#   'about',
#   'what',
#   'nasa',
#   'is',
#   'do',
#   'exist',
#   'program',
#   'stay',
#   'in',
#   'place',
#   'axe2x80xa6',
#   'httpstcorxn1lld6qa'],
#  ['brt',
#   'ryanrossuk',
#   'elonmusk',
#   'hope',
#   'you',
#   'like',
#   'my',
#   'model',
#   'x',
#   'custom',
#   'stori',
#   'your',
#   'someth',
#   'of',
#   'a',
#   'hero',
#   'of',
#   'mine',
#   'never',
#   'give',
#   'up',
#   'and',
#   'thank',
#   'you',
#   'httpsxe2x80xa6'],
#  ['brt',
#   'spacex',
#   'recoveri',
#   'team',
#   'en',
#   'rout',
#   'to',
#   'dragon',
#   'httpstco5aigcx0vs2'],
#  ['brt',
#   'spacex',
#   'more',
#   'photo',
#   'from',
#   'today',
#   'falcon',
#   '9',
#   'launch',
#   'xe2x86x92',
#   'httpstco095whwmtkp',
#   'httpstcoo2rkvlznak'],
#  ['brt',
#   'spacex',
#   'success',
#   'deploy',
#   'of',
#   'echostar',
#   'xxiii',
#   'to',
#   'a',
#   'geosynchron',
#   'transfer',
#   'orbit',
#   'confirm',
#   'httpstcolppwlo8ymn'],
#  ['brt',
#   'spacex',
#   'back',
#   'live',
#   'for',
#   'final',
#   'burn',
#   'and',
#   'satellit',
#   'deploy',
#   'xe2x86x92',
#   'httpstcogtc39ubc7z',
#   'httpstco8ftmsb9itp'],
#  ['brt', 'spacex', 'liftoff', 'httpstcogtc39ubc7z', 'httpstcoserafpcpy2'],
#  ['bcapnjesu',
#   'lurpatron',
#   'mkbhd',
#   'jakerawr',
#   '3',
#   'is',
#   'a',
#   'great',
#   'car',
#   'but',
#   'definit',
#   'model',
#   's'],
#  ['bkyleugh', 'good', 'point'],
#  ['bpriyancaford', 'i', 'wish', 'it', 'so', 'annoy'],
#  ['bfinal',
#   'an',
#   'explan',
#   'for',
#   'daylight',
#   'save',
#   'that',
#   'make',
#   'sens',
#   'httpstcokgpjhngrjo'],
#  ['bandreelijah', 'ok'],
#  ['bbizbuilderusa',
#   'mcannonbrook',
#   'it',
#   'been',
#   'a',
#   'bear',
#   'to',
#   'get',
#   'done',
#   'but',
#   'prob',
#   '10',
#   'day',
#   'or',
#   'so',
#   'depend',
#   'on',
#   'full',
#   'speed',
#   'autost',
#   'test',
#   'result'],
#  ['blegitbacon',
#   'mcannonbrook',
#   'look',
#   'forward',
#   'to',
#   'it',
#   'i',
#   'know',
#   'it',
#   'clich',
#   'but',
#   'lotr',
#   'is',
#   'my',
#   'favorit',
#   'book',
#   'ever',
#   'want',
#   'txe2x80xa6',
#   'httpstcouchiq8p3yb'],
#  ['b5allanlevito',
#   'mcannonbrook',
#   'vgroysman',
#   'sure',
#   'just',
#   'check',
#   'out',
#   'my',
#   'prior',
#   'tweet',
#   'on',
#   'price',
#   '250',
#   'kwh',
#   'at',
#   'pack',
#   'level',
#   'wxe2x80xa6',
#   'httpstcoej1uxkhrpr'],
#  ['bmcannonbrook',
#   'can',
#   'onli',
#   'happen',
#   'with',
#   'your',
#   'support',
#   'and',
#   'work',
#   'close',
#   'with',
#   'key',
#   'govt',
#   'and',
#   'util',
#   'leader',
#   'who',
#   'are',
#   'sxe2x80xa6',
#   'httpstcoalfagi0klb'],
#  ['bjust',
#   'want',
#   'to',
#   'write',
#   'a',
#   'note',
#   'of',
#   'appreci',
#   'to',
#   'the',
#   'mani',
#   'australian',
#   'who',
#   'came',
#   'out',
#   'in',
#   'support',
#   'of',
#   'the',
#   'batteri',
#   'plan',
#   'especi',
#   'mcannonbrook'],
#  ['bahpton16',
#   'i',
#   'love',
#   'wikipedia',
#   'just',
#   'get',
#   'better',
#   'over',
#   'time'],
#  ['bjmmzherrera',
#   'answer',
#   'is',
#   'complex',
#   'for',
#   'electr',
#   'motor',
#   'we',
#   'use',
#   'an',
#   'ac',
#   'induct',
#   'motor',
#   'fed',
#   'by',
#   'a',
#   'dc',
#   'pack',
#   'thru',
#   'an',
#   'igbt',
#   'invexe2x80xa6',
#   'httpstcouksjidzpaq'],
#  ['bwilliamwint',
#   'high',
#   'voltag',
#   'dc',
#   'is',
#   'for',
#   'sure',
#   'the',
#   'best',
#   'way',
#   'to',
#   'transmit',
#   'electr',
#   'over',
#   'long',
#   'distanc',
#   'good',
#   'explanatxe2x80xa6',
#   'httpstcoucz8o3tfm1'],
#  ['biron',
#   'direct',
#   'current',
#   'is',
#   'the',
#   'right',
#   'approach',
#   'today',
#   'even',
#   'though',
#   'altern',
#   'wa',
#   'right',
#   'in',
#   'the',
#   'past',
#   'solar',
#   'power',
#   'amp',
#   'electron',
#   'both',
#   'dc'],
#  ['byour',
#   'most',
#   'welcom',
#   'veri',
#   'excit',
#   'to',
#   'discuss',
#   'the',
#   'futur',
#   'of',
#   'electr',
#   'renew',
#   '+',
#   'storag',
#   'arguabl',
#   'biggest',
#   'disrxe2x80xa6',
#   'httpstcoczufwzkgj'],
#  ['bmcannonbrook',
#   'just',
#   'spoke',
#   'with',
#   'jayweatheril',
#   'premier',
#   'of',
#   'south',
#   'australia',
#   'veri',
#   'impress',
#   'govt',
#   'is',
#   'clearli',
#   'committxe2x80xa6',
#   'httpstcojnocwkvmxi'],
#  ['bshail',
#   'ye',
#   'but',
#   'ship',
#   'taxestariff',
#   'and',
#   'instal',
#   'labor',
#   'vari',
#   'by',
#   'countri',
#   'as',
#   'those',
#   'cost',
#   'are',
#   'beyond',
#   'our',
#   'control'],
#  ['bmcannonbrook',
#   '250kwh',
#   'at',
#   'the',
#   'pack',
#   'level',
#   'for',
#   '100mwh+',
#   'system',
#   'tesla',
#   'is',
#   'move',
#   'to',
#   'fix',
#   'and',
#   'open',
#   'price',
#   'and',
#   'term',
#   'for',
#   'all',
#   'product'],
#  ['bmcannonbrook',
#   'tesla',
#   'will',
#   'get',
#   'the',
#   'system',
#   'instal',
#   'and',
#   'work',
#   '100',
#   'day',
#   'from',
#   'contract',
#   'signatur',
#   'or',
#   'it',
#   'is',
#   'free',
#   'that',
#   'seriou',
#   'enough',
#   'for',
#   'you'],
#  ['bzedd', 'will', 'send', 'you', 'one'],
#  ['bsimonakitzu', 'selfhatr'],
#  ['bthank', 'jj'],
#  ['bhttpstco3ysxzq1evj'],
#  ['brt', 'teslamotor', 'project', 'loveday', 'httpstcok1snxjn15u'],
#  ['bthank',
#   'you',
#   'for',
#   'the',
#   'love',
#   'letter',
#   'that',
#   'sound',
#   'like',
#   'a',
#   'great',
#   'idea',
#   'well',
#   'do',
#   'it',
#   'httpstcoss2wmkogyk'],
#  ['bspacex',
#   'could',
#   'not',
#   'do',
#   'thi',
#   'without',
#   'nasa',
#   'cant',
#   'express',
#   'enough',
#   'appreci',
#   'httpstcouqpi60zav7'],
#  ['bjamesatbuzz',
#   'thi',
#   'is',
#   'not',
#   'true',
#   'tm',
#   'work',
#   'for',
#   'a',
#   'lot',
#   'of',
#   'peopl',
#   'and',
#   'that',
#   'great',
#   'but',
#   'ive',
#   'mayb',
#   'done',
#   'it',
#   '7',
#   'or',
#   '8',
#   'time',
#   'ever'],
#  ['bfli', 'me', 'to', 'the', 'moon', 'oknhttpstco6qt8m5shwn'],
#  ['bspacex', 'announc', 'tomorrow', 'at', '1pm', 'pst'],
#  ['bmactechgeniu', 'of', 'cours'],
#  ['bduediamond', 'mayb', 'one', 'of', 'those', 'too'],
#  ['broller', 'coaster', 'are', 'awesom'],
#  ['bjohnpaulbrew',
#   'someth',
#   'on',
#   'a',
#   'tristat',
#   'border',
#   'might',
#   'work',
#   'gigafactori',
#   'plu',
#   'nearbi',
#   'support',
#   'suppli',
#   'chain',
#   'need',
#   'a',
#   'veri',
#   'larg',
#   'workforc'],
#  ['bdonbarbieri', 'greencarreport', 'good', 'chanc', 'it', 'will'],
#  ['bdavidshepardson', 'bw', 'att', 'toysru', 'exactli'],
#  ['bmeganmurp',
#   'chrisfail',
#   'bw',
#   'i',
#   'didnt',
#   'pose',
#   'for',
#   'it',
#   'hope',
#   'that',
#   'obviou',
#   'or',
#   'want',
#   'me',
#   'on',
#   'cover',
#   'tunnel',
#   'bore',
#   'machin',
#   'pic',
#   'wd',
#   'be',
#   'way',
#   'better'],
#  ['badrianvolt',
#   'minor',
#   'improv',
#   'updat',
#   'thi',
#   'weekend',
#   'high',
#   'speed',
#   'autost',
#   'in',
#   'about',
#   'two',
#   'week'],
#  ['bexcel', 'tesla', 'model', 'x', 'review', 'httpstcowvog4pbo1o'],
#  ['bjust', 'post', 'a', 'video', 'httpstcorcv7mvi8r'],
#  ['bhttpstco6ve3yjostm'],
#  ['bbabi', 'came', 'back', 'httpstco5frhw3at2b'],
#  ['brt', 'spacex', 'falcon', '9', 'first', 'stage', 'ha', 'land', 'at', 'lz1'],
#  ['bmattnewbi', 'no'],
#  ['brt',
#   'nasa',
#   'right',
#   'on',
#   'schedul',
#   'solar',
#   'array',
#   'have',
#   'been',
#   'deploy',
#   'on',
#   'spacex',
#   'dragon',
#   'cargo',
#   'spacecraft',
#   'watch',
#   'httpstcomzkw5udsti',
#   'httpstxe2x80xa6'],
#  ['bxuanthai',
#   'system',
#   'wa',
#   'green',
#   'for',
#   'launch',
#   'i',
#   'call',
#   'it',
#   'off'],
#  ['bspacecom',
#   'they',
#   'are',
#   'often',
#   'right',
#   'but',
#   'in',
#   'thi',
#   'case',
#   'we',
#   'have',
#   'alreadi',
#   'retir',
#   'so',
#   'much',
#   'rampd',
#   'risk',
#   'on',
#   'dragon',
#   '2',
#   'that',
#   'i',
#   'feel',
#   'veri',
#   'confid',
#   'of',
#   '2018'],
#  ['bzperrin99',
#   'use',
#   'high',
#   'pressur',
#   'bleed',
#   'off',
#   'the',
#   'fuel',
#   'side',
#   'rp1',
#   'kerosen',
#   'turbopump',
#   'so',
#   'no',
#   'dedic',
#   'pump',
#   'or',
#   'fluid',
#   'need'],
#  ['bbtw',
#   '99',
#   'like',
#   'to',
#   'be',
#   'fine',
#   'close',
#   'loop',
#   'tvc',
#   'wd',
#   'overcom',
#   'error',
#   'but',
#   'that',
#   '1',
#   'chanc',
#   'isnt',
#   'worth',
#   'roll',
#   'the',
#   'dice',
#   'better',
#   'to',
#   'wait',
#   'a',
#   'day'],
#  ['bzybbbi',
#   'not',
#   'obvious',
#   'relat',
#   'to',
#   'the',
#   'veri',
#   'tini',
#   'helium',
#   'leak',
#   'but',
#   'also',
#   'not',
#   'out',
#   'of',
#   'the',
#   'question'],
#  ['bif',
#   'thi',
#   'is',
#   'the',
#   'onli',
#   'issu',
#   'flight',
#   'would',
#   'be',
#   'fine',
#   'but',
#   'need',
#   'to',
#   'make',
#   'sure',
#   'that',
#   'it',
#   'isnt',
#   'symptomat',
#   'of',
#   'a',
#   'more',
#   'signific',
#   'upstream',
#   'root',
#   'caus'],
#  ['ball',
#   'system',
#   'go',
#   'except',
#   'the',
#   'movement',
#   'trace',
#   'of',
#   'an',
#   'upper',
#   'stage',
#   'engin',
#   'steer',
#   'hydraul',
#   'piston',
#   'wa',
#   'slightli',
#   'odd',
#   'stand',
#   'down',
#   'to',
#   'investig'],
#  ['brt',
#   'spacex',
#   '1',
#   'hour',
#   'from',
#   'launch',
#   'of',
#   'falcon',
#   '9',
#   'amp',
#   'dragon',
#   'to',
#   'spacest',
#   'rocket',
#   'amp',
#   'weather',
#   'are',
#   'go',
#   'launch',
#   'at',
#   '1001am',
#   'et',
#   '1501',
#   'utc',
#   'httpstcxe2x80xa6'],
#  ['bcount',
#   'down',
#   'to',
#   'the',
#   'first',
#   'spacex',
#   'launch',
#   'from',
#   'the',
#   'apollo',
#   '11',
#   'launch',
#   'pad',
#   'tomorrow',
#   'morn',
#   'webcastxe2x80xa6',
#   'httpstcoupjtcmftt'],
#  ['brt',
#   'nasa',
#   'hear',
#   'from',
#   'expert',
#   'at',
#   '5pm',
#   'et',
#   'about',
#   'the',
#   'statu',
#   'of',
#   'tomorrow',
#   '1001am',
#   'et',
#   'spacex',
#   'cargo',
#   'launch',
#   'to',
#   'spacest',
#   'httpstcoojkhgkxe2x80xa6'],
#  ['bspacex', 'photo', 'httpstcoimedaut3ni'],
#  ['bprovid',
#   'dragon',
#   '2',
#   'demo',
#   'mission',
#   'go',
#   'well',
#   'spacex',
#   'is',
#   'highli',
#   'confid',
#   'of',
#   'be',
#   'abl',
#   'to',
#   'fli',
#   'us',
#   'astronaut',
#   'in',
#   '2018',
#   'httpstcousuto6qsi7'],
#  ['blook',
#   'like',
#   'we',
#   'are',
#   'go',
#   'for',
#   'launch',
#   'ad',
#   'an',
#   'abort',
#   'trigger',
#   'at',
#   't60',
#   'sec',
#   'for',
#   'pressur',
#   'decay',
#   'of',
#   'upper',
#   'stage',
#   'helium',
#   'spin',
#   'start',
#   'system'],
#  ['binvestig',
#   'a',
#   'veri',
#   'small',
#   'leak',
#   'in',
#   'the',
#   'upper',
#   'stage',
#   'if',
#   'ok',
#   'will',
#   'launch',
#   'tomorrow',
#   'httpstcobqf97lywn4'],
#  ['bemenietti',
#   'chafkin',
#   'ye',
#   'but',
#   'onli',
#   'deep',
#   'in',
#   'solid',
#   'rock',
#   'where',
#   'the',
#   'wall',
#   'are',
#   'selfsupport',
#   'and',
#   'concret',
#   'reinforc',
#   'arguabl',
#   'arent',
#   'need'],
#  ['bsc00b', 'it', 'much', 'easier', 'to', 'do', 'the', 'cgi', 'that', 'way'],
#  ['bdaylight',
#   'rocket',
#   'launch',
#   'amp',
#   'land',
#   'at',
#   'the',
#   'cape',
#   'thi',
#   'weekend',
#   'will',
#   'be',
#   'the',
#   '1st',
#   'spacex',
#   'flight',
#   'from',
#   'the',
#   'apollo',
#   'launch',
#   'pad',
#   'httpstcovr5lqjyapz'],
#  ['bphoebecoleman', 'i', 'use', 'that', 'one'],
#  ['bok',
#   'what',
#   'are',
#   'some',
#   'good',
#   'one',
#   'will',
#   'have',
#   'to',
#   'meter',
#   'these',
#   'out',
#   'hope',
#   'kid',
#   'cant',
#   'die',
#   'from',
#   'groan',
#   'too',
#   'much'],
#  ['bvrgtech', 'floydilici', 'they', 'are', 'do', 'india', 'proud'],
#  ['bosiris26', 'you', 'may', 'come', 'to', 'regret', 'that', 'request'],
#  ['blittledovah',
#   'yeah',
#   'exactli',
#   'so',
#   'that',
#   'make',
#   'it',
#   'cool',
#   'right'],
#  ['bfloydilici', 'yeah', 'awesom', 'achiev', 'by', 'isro', 'veri', 'impress'],
#  ['bappar',
#   'there',
#   'is',
#   'thi',
#   'thing',
#   'call',
#   'dad',
#   'joke',
#   'and',
#   'i',
#   'make',
#   'them'],
#  ['bludwigmorelo',
#   'your',
#   'right',
#   'i',
#   'cant',
#   'hide',
#   'ani',
#   'more',
#   'i',
#   'am',
#   'ironi',
#   'man'],
#  ['bsamcornwel',
#   'they',
#   'were',
#   'earlier',
#   'draft',
#   'that',
#   'i',
#   'accident',
#   'publish',
#   'i',
#   'said',
#   'the',
#   'same',
#   'thing',
#   'a',
#   'week',
#   'alreadi'],
#  ['bin',
#   'appreci',
#   'tesla',
#   'is',
#   'provid',
#   'all',
#   'repair',
#   'cost',
#   'free',
#   'of',
#   'charg',
#   'and',
#   'expedit',
#   'httpstcod68hnjccoq'],
#  ['bcongrat',
#   'to',
#   'the',
#   'tesla',
#   'owner',
#   'who',
#   'sacrif',
#   'damag',
#   'to',
#   'hi',
#   'own',
#   'car',
#   'to',
#   'bring',
#   'a',
#   'car',
#   'with',
#   'an',
#   'unconsci',
#   'driver',
#   'safe',
#   'to',
#   'a',
#   'stop'],
#  ['blollieshopmom',
#   'best',
#   'place',
#   'to',
#   'watch',
#   'is',
#   'on',
#   'the',
#   'cape',
#   'causeway'],
#  ['bseacitylight',
#   'nas2four',
#   'sound',
#   'like',
#   'the',
#   'tesla',
#   'powerwal',
#   'consum',
#   'and',
#   'powerpack',
#   'utilitycommerci',
#   'might',
#   'be',
#   'use'],
#  ['bfalcon',
#   '9',
#   'rocket',
#   'now',
#   'vertic',
#   'at',
#   'cape',
#   'canaver',
#   'on',
#   'launch',
#   'complex',
#   '39a',
#   'thi',
#   'is',
#   'the',
#   'same',
#   'launchxe2x80xa6',
#   'httpstcowy6dwrcer3'],
#  ['baccohen',
#   'megangeuss',
#   'arstechnica',
#   'exactli',
#   'what',
#   'thi',
#   'person',
#   'said',
#   'is',
#   'untru'],
#  ['brusulalrubail',
#   'markruffalo',
#   'guardian',
#   'pleas',
#   'check',
#   'your',
#   'fact',
#   'tesla',
#   'and',
#   'spacex',
#   'join',
#   'as',
#   'soon',
#   'as',
#   'we',
#   'receiv',
#   'the',
#   'file',
#   'which',
#   'wa',
#   'monday'],
#  ['brt',
#   'teslamotor',
#   'supercharg',
#   'avail',
#   'is',
#   'now',
#   'display',
#   'on',
#   'your',
#   'tesla',
#   'touchscreen',
#   'so',
#   'you',
#   'can',
#   'see',
#   'how',
#   'mani',
#   'stall',
#   'are',
#   'open',
#   'befor',
#   'you',
#   'arxe2x80xa6'],
#  ['bdknise', 'of', 'cours', 'it', 'will'],
#  ['bsundalj', 'should', 'all', 'be', 'upload', 'by', 'next', 'month'],
#  ['bsureal808',
#   'motor',
#   'trend',
#   'could',
#   'onli',
#   'achiev',
#   '24',
#   'sec',
#   'when',
#   'they',
#   'test',
#   'the',
#   'porsch',
#   '918'],
#  ['bvoltzcoreaudio',
#   'i',
#   'dont',
#   'know',
#   'what',
#   'make',
#   'you',
#   'think',
#   'that',
#   'a',
#   'rocket',
#   'it',
#   'complet',
#   'cover',
#   'in',
#   'a',
#   'tarpaulin'],
#  ['brt',
#   'spacex',
#   'target',
#   'feb',
#   '18',
#   'for',
#   'dragon',
#   'next',
#   'resuppli',
#   'mission',
#   'to',
#   'the',
#   'spacest',
#   'xe2x80x94',
#   'our',
#   '1st',
#   'launch',
#   'from',
#   'lc39a',
#   'at',
#   'nasa',
#   'kennedi',
#   'spacxe2x80xa6'],
#  ['bgeorg',
#   'schultz',
#   'and',
#   'jim',
#   'baker',
#   'articl',
#   'in',
#   'wsj',
#   'regard',
#   'a',
#   'carbon',
#   'tax',
#   'httpstcotf2urgms85'],
#  ['bbatlag', 'ye'],
#  ['bgoelishan', 'hope', 'for', 'summer', 'thi', 'year'],
#  ['bmdcdave',
#   'ye',
#   'altitud',
#   'improv',
#   'perform',
#   'for',
#   'electr',
#   'opposit',
#   'of',
#   'combust',
#   'car'],
#  ['bjovanik21',
#   'veidit',
#   'no',
#   'will',
#   'be',
#   'lower',
#   'wheelbas',
#   'cant',
#   'fit',
#   '100'],
#  ['bjovanik21',
#   'also',
#   'tesla',
#   'servic',
#   'can',
#   'remov',
#   'front',
#   'trunk',
#   'liner',
#   'if',
#   'you',
#   'dont',
#   'use',
#   'it',
#   'and',
#   'improv',
#   'perform',
#   'further'],
#  ['bveidit',
#   'no',
#   'plan',
#   'to',
#   'take',
#   'x',
#   's',
#   'or',
#   '3',
#   'abov',
#   '100',
#   'kwh',
#   'semi',
#   'necessarili',
#   'and',
#   'pickup',
#   'truck',
#   'mayb',
#   'will',
#   'go',
#   'abov'],
#  ['bjovanik21',
#   'take',
#   'out',
#   'the',
#   'floor',
#   'mat',
#   'and',
#   'it',
#   '227',
#   'mt',
#   'said',
#   'everyth',
#   'had',
#   'to',
#   'be',
#   'standard',
#   'product'],
#  ['bquickpi', 'ye'],
#  ['bproduct',
#   'tesla',
#   'model',
#   's',
#   'p100dl',
#   'set',
#   'motor',
#   'trend',
#   'alltim',
#   'world',
#   'record',
#   'to',
#   '60',
#   'mph',
#   'in',
#   '227',
#   'sec',
#   'httpstcosxalqrm5l'],
#  ['brt',
#   'verg',
#   'million',
#   'of',
#   'tesla',
#   'batteri',
#   'cell',
#   'are',
#   'power',
#   'thousand',
#   'of',
#   'la',
#   'home',
#   'httpstconjfzezafbv',
#   'httpstcoodgiakcjiv'],
#  ['bsign',
#   'off',
#   'now',
#   'that',
#   'wa',
#   'more',
#   'than',
#   'enough',
#   'twitter',
#   'troubl',
#   'for',
#   'one',
#   'morn'],
#  ['brt', 'stevecas', 'i', 'agre', 'httpstcomimeful5ho', 'httpstcopkfayb1qtx'],
#  ['bqriositi',
#   'mactechgeniu',
#   'no',
#   'rare',
#   'earth',
#   'metal',
#   'in',
#   'batteri'],
#  ['bcamdtor', 'trylk', 'almost', 'readi'],
#  ['bmactechgeniu',
#   'app',
#   'updat',
#   'is',
#   'about',
#   'two',
#   'week',
#   'out',
#   'linux',
#   'kernel',
#   'and',
#   'browser',
#   'updat',
#   'probabl',
#   'a',
#   'month',
#   'or',
#   'so',
#   'hw2',
#   'autopilot',
#   'ha',
#   'prioriti'],
#  ['bfredericlambert',
#   'ye',
#   'but',
#   'model',
#   '3',
#   'is',
#   'the',
#   'overwhelm',
#   'prioriti'],
#  ['bclayelli',
#   'i',
#   'will',
#   'post',
#   'an',
#   'articl',
#   'he',
#   'wrote',
#   'half',
#   'a',
#   'centuri',
#   'ago',
#   'about',
#   'fli',
#   'through',
#   'africa',
#   'and',
#   'asia',
#   'in',
#   'hi',
#   'plane',
#   'one',
#   'of',
#   'my',
#   'favorit',
#   'thing'],
#  ['bchristesla',
#   'fredericlambert',
#   'almost',
#   'there',
#   'we',
#   'are',
#   'just',
#   'be',
#   'veri',
#   'care',
#   'with',
#   'the',
#   'rollout'],
#  ['btrylk',
#   'a',
#   'lot',
#   'of',
#   'terribl',
#   'thing',
#   'could',
#   'happen',
#   'in',
#   'four',
#   'year',
#   'of',
#   'extrem',
#   'do',
#   'you',
#   'realli',
#   'want',
#   'anoth',
#   'war',
#   'that',
#   'where',
#   'extrem',
#   'lead'],
#  ['bfredericlambert',
#   'yeah',
#   'it',
#   'is',
#   'hard',
#   'to',
#   'convey',
#   'complex',
#   'idea',
#   'in',
#   '140',
#   'char',
#   'and',
#   'tone',
#   'is',
#   'lost',
#   'in',
#   'text'],
#  ['bcycletrad',
#   'rtoro20',
#   'peopl',
#   'should',
#   'push',
#   'to',
#   'have',
#   'as',
#   'mani',
#   'moder',
#   'advis',
#   'the',
#   'presid',
#   'as',
#   'possibl',
#   'blind',
#   'hate',
#   'is',
#   'never',
#   'the',
#   'right',
#   'answer'],
#  ['bwise1919', 'fredericlambert', 'roll', 'out', 'a', 'new', 'updat', 'today'],
#  ['breciph', 'we', 'should', 'tri', 'our', 'best'],
#  ['biamdevelop',
#   'realli',
#   'ok',
#   'i',
#   'will',
#   'work',
#   'harder',
#   'on',
#   'think',
#   'first',
#   'and',
#   'tweet',
#   'second',
#   'sorri',
#   'for',
#   'anyth',
#   'thoughtless'],
#  ['bmartinengwicht', 'fredericlambert', 'i', 'just', 'had', 'three', 'coffe'],
#  ['bthelogicbox',
#   'ianrosswin',
#   'mar',
#   'is',
#   'critic',
#   'for',
#   'the',
#   'longterm',
#   'surviv',
#   'of',
#   'human',
#   'and',
#   'life',
#   'on',
#   'earth',
#   'as',
#   'we',
#   'know',
#   'it'],
#  ['bseanbroswag', 'fredericlambert', 'numer'],
#  ['bb0turner',
#   'gravimetr',
#   'energi',
#   'densiti',
#   'of',
#   'batteri',
#   'and',
#   'achiev',
#   'a',
#   'high',
#   'cell',
#   'mass',
#   'fraction'],
#  ['btravelingmom23',
#   'i',
#   'love',
#   'canada',
#   'im',
#   'half',
#   'canadian',
#   'my',
#   'mom',
#   'wa',
#   'born',
#   'in',
#   'regina',
#   'my',
#   'grandfath',
#   'her',
#   'dad',
#   'wa',
#   'american',
#   'born',
#   'in',
#   'minnesota'],
#  ['bfredericlambert',
#   'me',
#   'too',
#   'i',
#   'hope',
#   'to',
#   'get',
#   'back',
#   'to',
#   'regularli',
#   'schedul',
#   'program',
#   'soon'],
#  ['bbrendangag',
#   'i',
#   'agre',
#   'great',
#   'countri',
#   'look',
#   'forward',
#   'to',
#   'take',
#   'my',
#   'kid',
#   'for',
#   'a',
#   'visit',
#   'ive',
#   'heard',
#   'it',
#   'is',
#   'incred',
#   'beauti'],
#  ['brtoro20',
#   'realli',
#   'i',
#   'alreadi',
#   'have',
#   'both',
#   'feet',
#   'in',
#   'my',
#   'mouth',
#   'and',
#   'am',
#   'levit',
#   'on',
#   'my',
#   'own',
#   'idioci'],
#  ['bdaringkid', 'true', 'me', 'be', 'one', 'of', 'them'],
#  ['bmarcelsalath',
#   'not',
#   'perfect',
#   'amp',
#   'cd',
#   'be',
#   'better',
#   'but',
#   '10th',
#   'out',
#   'of',
#   '200+',
#   'countri',
#   'with',
#   'onli',
#   'a',
#   '008',
#   'diff',
#   'to',
#   '1st',
#   'place',
#   'mean',
#   'it',
#   'essenti',
#   'on',
#   'par'],
#  ['bandresantoniop', 'fair', 'point', 'sorri'],
#  ['bactivist',
#   'should',
#   'be',
#   'push',
#   'for',
#   'more',
#   'moder',
#   'to',
#   'advis',
#   'presid',
#   'not',
#   'fewer',
#   'how',
#   'could',
#   'have',
#   'onli',
#   'extremist',
#   'advis',
#   'him',
#   'possibl',
#   'be',
#   'good'],
#  ['brealphillippoon', 'need', 'a', 'major', 'overhaul'],
#  ['bbencam137', 'fifthrocket', 'exactli'],
#  ['baanstadgard',
#   'norway',
#   'is',
#   'great',
#   'on',
#   'all',
#   'level',
#   'love',
#   'norway'],
#  ['bbullflag', 'yeah', 'and', 'twitter', 'is', 'a', 'hater', 'hellscap'],
#  ['bw4a',
#   'good',
#   'grief',
#   'im',
#   'not',
#   'work',
#   'for',
#   'trump',
#   'im',
#   'tri',
#   'to',
#   'provid',
#   'advic',
#   'that',
#   'help',
#   'take',
#   'thing',
#   'in',
#   'a',
#   'more',
#   'posit',
#   'direct'],
#  ['bbittermerci', 'callumk24', 'actual', 'i', 'think', 'it', 'kinda', 'cool'],
#  ['berichaegl',
#   'ilexomat',
#   'isnt',
#   'that',
#   'basic',
#   'like',
#   'have',
#   'a',
#   'juri',
#   'of',
#   'peer',
#   'that',
#   'is',
#   'a',
#   'default',
#   'option',
#   'in',
#   'the',
#   'us'],
#  ['bvladsavov',
#   'those',
#   'countri',
#   'have',
#   'strong',
#   'justic',
#   'system',
#   'but',
#   'id',
#   'put',
#   'them',
#   'roughli',
#   'on',
#   'par',
#   'with',
#   'us',
#   'that',
#   'rate',
#   'system',
#   'conflat',
#   'mani',
#   'factor'],
#  ['bfifthrocket',
#   'did',
#   'you',
#   'read',
#   'my',
#   'tweet',
#   'i',
#   'attack',
#   'it',
#   'hard',
#   'did',
#   'not',
#   'defend'],
#  ['bkenemon',
#   'your',
#   'right',
#   'polit',
#   'is',
#   'a',
#   'nowin',
#   'situat',
#   'somebodi',
#   'is',
#   'go',
#   'to',
#   'hate',
#   'what',
#   'you',
#   'say',
#   'no',
#   'matter',
#   'what',
#   'that',
#   'is'],
#  ['bmartinengwicht',
#   'also',
#   'good',
#   'there',
#   'are',
#   'sever',
#   'that',
#   'are',
#   'on',
#   'par',
#   'with',
#   'us',
#   'just',
#   'dont',
#   'think',
#   'ani',
#   'are',
#   'better',
#   'peopl',
#   'confus',
#   'law',
#   'with',
#   'court'],
#  ['bpaulvankeep', 'mostli', 'antidrug', 'law'],
#  ['bzgiarrizzo', 'exactli'],
#  ['bthelaadam',
#   'the',
#   'law',
#   'need',
#   'to',
#   'chang',
#   'judg',
#   'are',
#   'respons',
#   'for',
#   'evalu',
#   'whether',
#   'an',
#   'action',
#   'break',
#   'the',
#   'law',
#   'not',
#   'make',
#   'law'],
#  ['bhumplik', 'the', 'remedi', 'for', 'that', 'is', 'chang', 'the', 'law'],
#  ['bcallumk24', 'ok', 'but', 'what', 'up', 'the', 'wig'],
#  ['bilexomat',
#   'there',
#   'are',
#   'mani',
#   'good',
#   'legal',
#   'system',
#   'on',
#   'par',
#   'with',
#   'us',
#   'just',
#   'dont',
#   'know',
#   'ani',
#   'that',
#   'are',
#   'better'],
#  ['bbiesseman', 'true'],
#  ['bmani',
#   'in',
#   'america',
#   'dont',
#   'realiz',
#   'how',
#   'proud',
#   'they',
#   'should',
#   'be',
#   'of',
#   'the',
#   'legal',
#   'system',
#   'not',
#   'perfect',
#   'but',
#   'nowher',
#   'is',
#   'the',
#   'caus',
#   'of',
#   'justic',
#   'better',
#   'serv'],
#  ['brt',
#   'teslamotor',
#   'honor',
#   'to',
#   'receiv',
#   'best',
#   'car',
#   'award',
#   'for',
#   'the',
#   'third',
#   'year',
#   'in',
#   'a',
#   'row',
#   'in',
#   'germani',
#   'thank',
#   'you',
#   'to',
#   'all',
#   '124000',
#   'of',
#   'you',
#   'who',
#   'vote',
#   'httpsxe2x80xa6'],
#  ['bwalk', 'down', 'the', 'street', 'and', 'saw', 'thi', 'httpstcompv5j6088k'],
#  ['bchrisjcav', 'mayb', 'my', 'favorit', 'mug', 'ever'],
#  ['bnintendomaniac', 'alext4627', 'i', 'wish'],
#  ['boldmanriver1800',
#   'then',
#   'so',
#   'be',
#   'it',
#   'id',
#   'rather',
#   'do',
#   'what',
#   'i',
#   'believ',
#   'is',
#   'right',
#   'than',
#   'do',
#   'what',
#   'appear',
#   'right',
#   'simpli',
#   'to',
#   'avoid',
#   'critic'],
#  ['bbonnienorman', 'advanderm', 'wow', 'cool'],
#  ['balext4627', 'that', 'exactli', 'what', 'i', 'thought', 'love', 'halflif'],
#  ['banalontana', 'nuanc', 'are', 'import'],
#  ['brainbow', 'unicorn', 'and', 'electr', 'car', 'httpstcooghkvumpdi'],
#  ['b26',
#   'ft',
#   'diamet',
#   'tunnel',
#   'run',
#   '2',
#   'mile',
#   'under',
#   'dc',
#   'httpstcoxfqkioesg8'],
#  ['beveegdmann',
#   'realli',
#   'dont',
#   'want',
#   'to',
#   'get',
#   'in',
#   'polit',
#   'i',
#   'just',
#   'want',
#   'to',
#   'help',
#   'invent',
#   'and',
#   'develop',
#   'technolog',
#   'that',
#   'improv',
#   'live',
#   'feel',
#   'so',
#   'bizarr'],
#  ['bdaniellebloem',
#   'ye',
#   'for',
#   'now',
#   'but',
#   'thi',
#   'should',
#   'be',
#   'address',
#   'on',
#   'all',
#   'front',
#   'judici',
#   'legisl',
#   'and',
#   'execut'],
#  ['bin',
#   'addit',
#   'i',
#   'again',
#   'rais',
#   'climat',
#   'i',
#   'believ',
#   'thi',
#   'is',
#   'do',
#   'good',
#   'so',
#   'will',
#   'remain',
#   'on',
#   'council',
#   'amp',
#   'keep',
#   'at',
#   'it',
#   'do',
#   'otherwis',
#   'would',
#   'be',
#   'wrong'],
#  ['bat',
#   'my',
#   'request',
#   'the',
#   'agenda',
#   'for',
#   'yesterday',
#   'white',
#   'hous',
#   'meet',
#   'went',
#   'from',
#   'not',
#   'mention',
#   'the',
#   'travel',
#   'ban',
#   'to',
#   'have',
#   'it',
#   'be',
#   'first',
#   'and',
#   'foremost'],
#  ['bpetergleick',
#   'busi',
#   'first',
#   'ive',
#   'heard',
#   'of',
#   'thi',
#   'meet',
#   'will',
#   'find',
#   'out',
#   'whi'],
#  ['bofficeofomar', 'mayb'],
#  ['bvideo',
#   'of',
#   'mit',
#   'entrant',
#   'into',
#   'the',
#   'spacex',
#   'hyperloop',
#   'competit',
#   'air',
#   'ha',
#   'been',
#   'remov',
#   'from',
#   'the',
#   'hyperloop',
#   'tube',
#   'to',
#   'almoxe2x80xa6',
#   'httpstcoftgshkcarf'],
#  ['bminecraft', 'httpstcolu1yzjjloz'],
#  ['bmcun1',
#   'ye',
#   'green',
#   'card',
#   'amp',
#   'dual',
#   'citizen',
#   'alreadi',
#   'ok',
#   'work',
#   'amp',
#   'spousal',
#   'visa',
#   'not',
#   'yet',
#   'but',
#   'hope',
#   'soon',
#   'thi',
#   'is',
#   'separ',
#   'from',
#   'judici',
#   'action'],
#  ['bthere',
#   'ha',
#   'alreadi',
#   'been',
#   'and',
#   'there',
#   'will',
#   'be',
#   'progress',
#   'on',
#   'thi',
#   'matter'],
#  ['bregard',
#   'the',
#   'meet',
#   'at',
#   'the',
#   'white',
#   'hous',
#   'httpstco8b1xh4ow6h'],
#  ['blotteworld', 'ye'],
#  ['brt',
#   'wire',
#   'the',
#   'ai',
#   'that',
#   'beat',
#   'the',
#   'world',
#   'best',
#   'poker',
#   'player',
#   'mimick',
#   'human',
#   'intuit',
#   'in',
#   'a',
#   'way',
#   'no',
#   'other',
#   'machin',
#   'ever',
#   'had',
#   'httpstco30mkagfxe2x80xa6'],
#  ['bsarahfkessl',
#   'qz',
#   'headlin',
#   'amp',
#   'articl',
#   'is',
#   'mislead',
#   'i',
#   'said',
#   'it',
#   'wont',
#   'be',
#   'retract',
#   'ie',
#   'withdrawn',
#   'by',
#   'pre',
#   'it',
#   'may',
#   'bexe2x80xa6',
#   'httpstcofpiawarhz1'],
#  ['breesandersen',
#   'flixrisk',
#   'ye',
#   'i',
#   'believ',
#   'that',
#   'is',
#   'critic',
#   'to',
#   'ensur',
#   'a',
#   'good',
#   'futur',
#   'for',
#   'human'],
#  ['btop',
#   'ai',
#   'research',
#   'agre',
#   'on',
#   'principl',
#   'for',
#   'develop',
#   'benef',
#   'ai',
#   'httpstcocatbd4oidf'],
#  ['brt',
#   'teslamotor',
#   'meet',
#   'the',
#   'util',
#   'grid',
#   'of',
#   'the',
#   'futur',
#   'tesla',
#   'powerpack',
#   'instal',
#   'at',
#   'sce',
#   'substat',
#   'will',
#   'reduc',
#   'the',
#   'la',
#   'basin',
#   'relianxe2x80xa6'],
#  ['binhaleray',
#   'i',
#   'agre',
#   'with',
#   'creat',
#   'great',
#   'job',
#   'restor',
#   'us',
#   'strength',
#   'as',
#   'a',
#   'great',
#   'manufactur',
#   'of',
#   'product',
#   'and',
#   'anythingxe2x80xa6',
#   'httpstco2lwdbdleo0'],
#  ['bmcwm', 'jackclarksf', 'yeah', 'sorri', 'about', 'that'],
#  ['bjacobofamb',
#   'ye',
#   'the',
#   'order',
#   'is',
#   'still',
#   'bad',
#   'but',
#   'it',
#   'is',
#   'alway',
#   'import',
#   'to',
#   'read',
#   'the',
#   'sourc',
#   'materi'],
#  ['bread',
#   'the',
#   'sourc',
#   'materi',
#   'is',
#   'better',
#   'than',
#   'read',
#   'other',
#   'peopl',
#   'opinion',
#   'about',
#   'the',
#   'sourc',
#   'materi',
#   'httpstcohkiykbdb3g'],
#  ['brt',
#   'hyperloop',
#   'congrat',
#   'to',
#   'warr',
#   'hyperloop',
#   'team',
#   'for',
#   'fastest',
#   'podflew',
#   'down',
#   'entir',
#   'length',
#   'of',
#   'track',
#   'at',
#   'the',
#   'world',
#   'first',
#   'hyperloop',
#   'competitionxe2x80xa6'],
#  ['brt',
#   'hyperloop',
#   'watch',
#   'live',
#   'replay',
#   'now',
#   'of',
#   'both',
#   'mit',
#   'and',
#   'warr',
#   'hyperloop',
#   'test',
#   'flight',
#   'at',
#   'httpstcocoiedeujwn',
#   'breakapod',
#   'httpstco7rlylmxe2x80xa6'],
#  ['brt',
#   'hyperloop',
#   'watchliv',
#   'now',
#   'at',
#   'httpstcocoiedeujwn',
#   'as',
#   'warr',
#   'hyperloop',
#   'team',
#   'attempt',
#   'their',
#   'first',
#   'flight',
#   'in',
#   'the',
#   'spacex',
#   'hyperloop',
#   'test',
#   'trxe2x80xa6'],
#  ['bdanahul', 'strateg', 'amp', 'polici', 'forum'],
#  ['bdanmoran3',
#   'redletterdav',
#   'exactli',
#   'there',
#   'is',
#   'no',
#   'possibl',
#   'of',
#   'retract',
#   'but',
#   'there',
#   'is',
#   'possibl',
#   'of',
#   'modificationxe2x80xa6',
#   'httpstcogweer63awo'],
#  ['bpleas',
#   'read',
#   'immigr',
#   'order',
#   'lmk',
#   'specif',
#   'amend',
#   'will',
#   'seek',
#   'advisori',
#   'council',
#   'consensu',
#   'amp',
#   'present',
#   'to',
#   'presid',
#   'httpstcoqlpbsp4lek'],
#  ['bparparv', 'it', 'is', 'not'],
#  ['bmani',
#   'peopl',
#   'neg',
#   'affect',
#   'by',
#   'thi',
#   'polici',
#   'are',
#   'strong',
#   'support',
#   'of',
#   'the',
#   'us',
#   'theyv',
#   'done',
#   'rightnot',
#   'wrong',
#   'amp',
#   'dont',
#   'deserv',
#   'to',
#   'be',
#   'reject'],
#  ['bthe',
#   'blanket',
#   'entri',
#   'ban',
#   'on',
#   'citizen',
#   'from',
#   'certain',
#   'primarili',
#   'muslim',
#   'countri',
#   'is',
#   'not',
#   'the',
#   'best',
#   'way',
#   'to',
#   'address',
#   'the',
#   'countryxe2x80x99',
#   'challeng'],
#  ['bmiguelgamino',
#   'popsci',
#   'thi',
#   'is',
#   'silli',
#   'if',
#   'ad',
#   'lane',
#   'actual',
#   'did',
#   'make',
#   'it',
#   'wors',
#   'that',
#   'would',
#   'impli',
#   'remov',
#   'lane',
#   'maxe2x80xa6',
#   'httpstco0fr5cubdrn'],
#  ['band',
#   'we',
#   'start',
#   'dig',
#   'the',
#   'tunnel',
#   'tonight',
#   'httpstcouysiu0qg34'],
#  ['brt',
#   'techinsid',
#   'here',
#   'are',
#   'all',
#   'the',
#   'futurist',
#   'pod',
#   'compet',
#   'in',
#   'elon',
#   'musk',
#   'hyperloop',
#   'competit',
#   'thi',
#   'weekend',
#   'httpstcoiv8ngurqkh',
#   'httpsxe2x80xa6'],
#  ['bhyperloop',
#   'pod',
#   'race',
#   'happen',
#   'thi',
#   'weekend',
#   'at',
#   'spacex',
#   'hq',
#   'near',
#   'lax',
#   'we',
#   'built',
#   'a',
#   'mile',
#   'long',
#   'vacuum',
#   'tube',
#   'on',
#   'our',
#   'campu',
#   'big',
#   'enough',
#   'to',
#   'fit',
#   'peopl'],
#  ['bsuzieoffici',
#   'yeah',
#   'am',
#   'hear',
#   'thi',
#   'from',
#   'a',
#   'lot',
#   'of',
#   'peopl',
#   'amp',
#   'it',
#   'get',
#   'me',
#   'down',
#   'im',
#   'just',
#   'tri',
#   'to',
#   'make',
#   'a',
#   'positixe2x80xa6',
#   'httpstcoin6sqs586'],
#  ['brt',
#   'hyperloop',
#   'team',
#   'arriv',
#   'today',
#   'for',
#   'test',
#   'week',
#   'befor',
#   'firstev',
#   'hyperloop',
#   'competit',
#   'at',
#   'spacex',
#   'hq',
#   'on',
#   'jan',
#   '2729',
#   'xe2x86x92',
#   'httpstcomhrfcxe2x80xa6'],
#  ['brt',
#   'gizmodo',
#   'a',
#   'brief',
#   'chat',
#   'with',
#   'elon',
#   'musk',
#   'about',
#   'climat',
#   'chang',
#   'rex',
#   'tillerson',
#   'and',
#   'donald',
#   'trump',
#   'httpstcoijo34uedsq',
#   'httpstcoxryj3dqxe2x80xa6'],
#  ['btheskinsfactori',
#   'earthquak',
#   'tend',
#   'to',
#   'have',
#   'the',
#   'biggest',
#   'effect',
#   'on',
#   'the',
#   'surfac',
#   'like',
#   'wave',
#   'on',
#   'water',
#   'that',
#   'whi',
#   'la',
#   'canxe2x80xa6',
#   'httpstcotaeytlojpd'],
#  ['bwsimson',
#   'start',
#   'across',
#   'from',
#   'my',
#   'desk',
#   'at',
#   'spacex',
#   'crenshaw',
#   'and',
#   'the',
#   '105',
#   'freeway',
#   'which',
#   'is',
#   '5',
#   'min',
#   'from',
#   'lax'],
#  ['bclayelli', 'yup'],
#  ['bbelovedrevol', 'mayb', 'next', 'month'],
#  ['bexcit',
#   'progress',
#   'on',
#   'the',
#   'tunnel',
#   'front',
#   'plan',
#   'to',
#   'start',
#   'dig',
#   'in',
#   'a',
#   'month',
#   'or',
#   'so'],
#  ['brex',
#   'tillerson',
#   'support',
#   'a',
#   'carbon',
#   'tax',
#   'thi',
#   'is',
#   'what',
#   'is',
#   'realli',
#   'need',
#   'to',
#   'move',
#   'the',
#   'needl',
#   'httpstco6ne01tozs1'],
#  ['brt',
#   'gizmodo',
#   'whi',
#   'it',
#   'matter',
#   'that',
#   'human',
#   'poker',
#   'pro',
#   'are',
#   'get',
#   'trounc',
#   'by',
#   'an',
#   'ai',
#   'httpstcolezbofy8iv',
#   'httpstco4dhlqrf9hb'],
#  ['bmichaelemann',
#   'im',
#   'just',
#   'say',
#   'that',
#   'we',
#   'should',
#   'see',
#   'what',
#   'happen',
#   'first',
#   'the',
#   'action',
#   'may',
#   'be',
#   'surpris'],
#  ['bmichaelemann', 'no', 'they', 'dont'],
#  ['bnivo0o0', 'wa', 'wonder', 'what', 'those', 'were'],
#  ['bsigh'],
#  ['bmichaelmclean',
#   'that',
#   'may',
#   'be',
#   'a',
#   'difficult',
#   'award',
#   'to',
#   'declin'],
#  ['btillerson',
#   'also',
#   'said',
#   'that',
#   'xe2x80x9cth',
#   'risk',
#   'of',
#   'climat',
#   'chang',
#   'doe',
#   'existxe2x80x9d',
#   'and',
#   'he',
#   'believ',
#   'xe2x80x9cact',
#   'should',
#   'be',
#   'taken'],
#  ['btheeconomist',
#   'on',
#   'how',
#   'to',
#   'address',
#   'threat',
#   'of',
#   'climat',
#   'chang',
#   'they',
#   'do',
#   'requir',
#   'a',
#   'global',
#   'respons'],
#  ['btheeconomist',
#   'tillerson',
#   'at',
#   'hi',
#   'confirm',
#   'hear',
#   'i',
#   'think',
#   'itxe2x80x99',
#   'import',
#   'that',
#   'the',
#   'unit',
#   'state',
#   'maintain',
#   'it',
#   'sexe2x80xa6',
#   'httpstcoxrkpitbae'],
#  ['bredletterdav',
#   'ok',
#   'fine',
#   'soldier',
#   '76',
#   'my',
#   'dark',
#   'secret',
#   'is',
#   'out'],
#  ['bdanahul',
#   'i',
#   'share',
#   'the',
#   'economist',
#   'opinion',
#   'that',
#   'he',
#   'should',
#   'be',
#   'given',
#   'the',
#   'benefit',
#   'of',
#   'the',
#   'doubt',
#   'unless',
#   'hi',
#   'action',
#   'prove',
#   'otherwis'],
#  ['bdanahul',
#   'rex',
#   'is',
#   'an',
#   'except',
#   'compet',
#   'execut',
#   'understand',
#   'geopolit',
#   'and',
#   'know',
#   'how',
#   'to',
#   'win',
#   'for',
#   'hi',
#   'team',
#   'hi',
#   'team',
#   'is',
#   'now',
#   'the',
#   'usa'],
#  ['btheeconomist',
#   'thi',
#   'may',
#   'sound',
#   'surpris',
#   'come',
#   'from',
#   'me',
#   'but',
#   'i',
#   'agre',
#   'with',
#   'the',
#   'economist',
#   'rex',
#   'tillerson',
#   'ha',
#   'the',
#   'potenxe2x80xa6',
#   'httpstco2bddsk9ibi'],
#  ['bdeanarexd',
#   'there',
#   'will',
#   'be',
#   'a',
#   'softwar',
#   'updat',
#   'thi',
#   'weekend',
#   'that',
#   'improv',
#   'selfcalibr',
#   'abil'],
#  ['brt',
#   'neiltyson',
#   'in',
#   '1927',
#   'lindbergh',
#   'flew',
#   'from',
#   'ny',
#   'to',
#   'pari',
#   '45',
#   'yr',
#   'later',
#   'in',
#   '1972',
#   'we',
#   'last',
#   'walk',
#   'on',
#   'the',
#   'moon',
#   '45',
#   'yr',
#   'later',
#   'in',
#   '2017',
#   'wexe2x80xa6',
#   'wexe2x80xa6',
#   'wexe2x80xa6'],
#  ['btsrandal', '3', 'month', 'mayb', '6', 'month', 'definit'],
#  ['bstephenstohn',
#   'ye',
#   'safeti',
#   'should',
#   'improv',
#   'significantli',
#   'due',
#   'to',
#   'autonomi',
#   'featur',
#   'even',
#   'if',
#   'reg',
#   'disallow',
#   'no',
#   'driver',
#   'present'],
#  ['bauto',
#   'steer',
#   'limit',
#   'to',
#   '45',
#   'mph',
#   'on',
#   'highway',
#   'for',
#   'now',
#   'ie',
#   'heavi',
#   'traffic',
#   'where',
#   'it',
#   'is',
#   'need',
#   'most',
#   'limit',
#   'will',
#   'rais',
#   'as',
#   'we',
#   'get',
#   'more',
#   'data'],
#  ['bdnansink40',
#   'autonomi',
#   'capabl',
#   'should',
#   'improv',
#   'via',
#   'ota',
#   'everi',
#   '2',
#   'to',
#   '6',
#   'week'],
#  ['bthesammyyyd', 'for', 'now'],
#  ['bhendrikstruik',
#   'the',
#   '100d',
#   'price',
#   'take',
#   'into',
#   'account',
#   'exchang',
#   'rate',
#   'shift',
#   'wherea',
#   'other',
#   'vehicl',
#   'price',
#   'havent',
#   'yet',
#   'been',
#   'adjust'],
#  ['bgdoehn',
#   'reddit',
#   'ye',
#   'block',
#   '5',
#   'is',
#   'the',
#   'final',
#   'upgrad',
# ...
#   'on',
#   'road',
#   'just',
#   'a',
#   'side',
#   'project',
#   'limit',
#   'market',
#   'potenti'],
#  ['bwe',
#   'def',
#   'dont',
#   'recommend',
#   'thi',
#   'but',
#   'model',
#   's',
#   'float',
#   'well',
#   'enough',
#   'to',
#   'turn',
#   'it',
#   'into',
#   'a',
#   'boat',
#   'for',
#   'short',
#   'period',
#   'of',
#   'time',
#   'thrust',
#   'via',
#   'wheel',
#   'rotat'],
#  ['btesla',
#   'owner',
#   'drive',
#   'through',
#   'a',
#   'flood',
#   'tunnel',
#   'amp',
#   'out',
#   'the',
#   'other',
#   'side',
#   'nhttpstcormpxdzshhq'],
#  ['ba',
#   'mention',
#   'at',
#   'the',
#   'begin',
#   'of',
#   'the',
#   'year',
#   'im',
#   'expect',
#   '70',
#   'success',
#   'rate',
#   'on',
#   'land',
#   'for',
#   'the',
#   'year',
#   '2016',
#   'is',
#   'the',
#   'year',
#   'of',
#   'experiment'],
#  ['blook',
#   'like',
#   'earli',
#   'liquid',
#   'oxygen',
#   'deplet',
#   'caus',
#   'engin',
#   'shutdown',
#   'just',
#   'abov',
#   'the',
#   'deck',
#   'httpstcosa6uckpkni'],
#  ['bturn',
#   'out',
#   'the',
#   'land',
#   'wa',
#   'not',
#   'as',
#   'fast',
#   'we',
#   'thought',
#   'but',
#   'still',
#   'hard',
#   'enough',
#   'to',
#   'destroy',
#   'the',
#   'primari',
#   'airfram',
#   'and',
#   'accordion',
#   'the',
#   'engin'],
#  ['bfucktyl', 'thank', 'tyler'],
#  ['bland',
#   'video',
#   'will',
#   'be',
#   'post',
#   'when',
#   'we',
#   'gain',
#   'access',
#   'to',
#   'camera',
#   'on',
#   'the',
#   'droneship',
#   'later',
#   'today',
#   'mayb',
#   'hardest',
#   'impact',
#   'to',
#   'date',
#   'droneship',
#   'still',
#   'ok'],
#  ['bupgrad',
#   'underway',
#   'to',
#   'enabl',
#   'rocket',
#   'to',
#   'compens',
#   'for',
#   'a',
#   'thrust',
#   'shortfal',
#   'on',
#   'one',
#   'of',
#   'the',
#   'three',
#   'land',
#   'engin',
#   'probabl',
#   'get',
#   'there',
#   'end',
#   'of',
#   'year'],
#  ['bastroorionmk', 'badastronom', 'quit', 'rapid', 'ye'],
#  ['brud', '=', 'rapid', 'unschedul', 'disassembl'],
#  ['blook',
#   'like',
#   'thrust',
#   'wa',
#   'low',
#   'on',
#   '1',
#   'of',
#   '3',
#   'land',
#   'engin',
#   'high',
#   'g',
#   'land',
#   'v',
#   'sensit',
#   'to',
#   'all',
#   'engin',
#   'oper',
#   'at',
#   'max'],
#  ['bascent',
#   'phase',
#   'amp',
#   'satellit',
#   'look',
#   'good',
#   'but',
#   'booster',
#   'rocket',
#   'had',
#   'a',
#   'rud',
#   'on',
#   'droneship'],
#  ['brt',
#   'spacex',
#   'target',
#   'launch',
#   'tomorrow',
#   'of',
#   'eutelsatsa',
#   'amp',
#   'ab',
#   'commun',
#   'satellit',
#   '45min',
#   'window',
#   'open',
#   '1029am',
#   'et',
#   '229pm',
#   'utc',
#   'httpstxe2x80xa6'],
#  ['bhighli',
#   'recommend',
#   'anyth',
#   'by',
#   'sean',
#   'carrol',
#   'httpstcoyvbcezm0io'],
#  ['bseanmcarrol',
#   'am',
#   'concern',
#   'that',
#   'advanc',
#   'life',
#   'may',
#   'be',
#   'inher',
#   'unstabl',
#   'arguabl',
#   'ani',
#   'civ',
#   'capabl',
#   'of',
#   'extinguish',
#   'itself',
#   'eventu',
#   'will'],
#  ['bseanmcarrol',
#   'life',
#   'you',
#   'can',
#   'talk',
#   'to',
#   'is',
#   'anoth',
#   'matter',
#   'of',
#   'cours',
#   'mani',
#   'mani',
#   'order',
#   'of',
#   'magnitud',
#   'less',
#   'like'],
#  ['bseanmcarrol',
#   'no',
#   'way',
#   'look',
#   'at',
#   'chemotroph',
#   'and',
#   'extremophil',
#   'primit',
#   'life',
#   'is',
#   'bloodi',
#   'everywher',
#   'highli',
#   'under',
#   'the',
#   'ice',
#   'on',
#   'europa',
#   'imo'],
#  ['bspoit',
#   'rsmoz',
#   'henc',
#   'the',
#   'urgenc',
#   'of',
#   'make',
#   'life',
#   'as',
#   'we',
#   'know',
#   'it',
#   'multiplanetari',
#   'as',
#   'soon',
#   'as',
#   'possibl'],
#  ['brsmoz',
#   'that',
#   'speed',
#   'of',
#   'light',
#   'constraint',
#   'and',
#   'quantum',
#   'mechan'],
#  ['band', 'no', 'im', 'not', 'an', 'alienbut', 'i', 'use', 'to', 'be', 'one'],
#  ['blatest',
#   'scienc',
#   'predict',
#   'gt',
#   'trillion',
#   'alien',
#   'civil',
#   'either',
#   'they',
#   'dont',
#   'last',
#   'long',
#   'or',
#   'there',
#   'are',
#   'a',
#   'lot',
#   'of',
#   'alien',
#   'httpstcooc9b2fluuf'],
#  ['bbenjaminrphoto',
#   'stephenpac',
#   'yeah',
#   'that',
#   'match',
#   'what',
#   'weve',
#   'found',
#   'so',
#   'far',
#   'more',
#   'like',
#   'unhing',
#   'than',
#   'nefari'],
#  ['bwould',
#   'seem',
#   'to',
#   'indic',
#   'that',
#   'one',
#   'or',
#   'more',
#   'peopl',
#   'sought',
#   'to',
#   'creat',
#   'the',
#   'fals',
#   'impress',
#   'of',
#   'a',
#   'safeti',
#   'issu',
#   'where',
#   'none',
#   'exist',
#   'q',
#   'is',
#   'whi'],
#  ['bof',
#   'greater',
#   'concern',
#   '37',
#   'of',
#   '40',
#   'suspens',
#   'complaint',
#   'to',
#   'nhtsa',
#   'were',
#   'fraudul',
#   'ie',
#   'fals',
#   'locat',
#   'or',
#   'vehicl',
#   'identif',
#   'number',
#   'were',
#   'use'],
#  ['bnhtsa',
#   'confirm',
#   'today',
#   'that',
#   'they',
#   'found',
#   'no',
#   'safeti',
#   'concern',
#   'with',
#   'the',
#   'model',
#   's',
#   'suspens',
#   'and',
#   'have',
#   'no',
#   'further',
#   'need',
#   'for',
#   'data',
#   'from',
#   'us',
#   'on',
#   'thi',
#   'matter'],
#  ['bdeftechpat', 'that', 'is', 'correct', 'it', 'wa', 'about', 'innov'],
#  ['bnice',
#   'comment',
#   'about',
#   'the',
#   'model',
#   's',
#   'by',
#   'cvk',
#   'on',
#   'topgearbbca',
#   'httpstcoulen51onng'],
#  ['brt', 'teslamotor', 'a', 'grain', 'of', 'salt', 'httpstcogpmyjl939x'],
#  ['brt',
#   'teslamotor',
#   'after',
#   'incent',
#   'thi',
#   'make',
#   'the',
#   'price',
#   '585k',
#   'feder',
#   'and',
#   '56k',
#   'in',
#   'california',
#   'httpstcolxcexgh3aj'],
#  ['badamhuet', 'no'],
#  ['bsometh', 'about', 'a', 'fli', 'metal', 'suitnnhttpstco6z1d9iz1fv'],
#  ['bdanahul', 'ye'],
#  ['bs', 'and', 'x', 'cell', 'are', 'also', 'panason'],
#  ['bwould',
#   'like',
#   'to',
#   'clarifi',
#   'that',
#   'tesla',
#   'is',
#   'work',
#   'exclus',
#   'with',
#   'panason',
#   'for',
#   'model',
#   '3',
#   'cell',
#   'news',
#   'articl',
#   'claim',
#   'otherwis',
#   'are',
#   'incorrect'],
#  ['bfourth',
#   'rocket',
#   'arriv',
#   'in',
#   'the',
#   'hangar',
#   'aim',
#   'for',
#   'first',
#   'reflight',
#   'in',
#   'septoct',
#   'httpstcotqw8d6cc3u'],
#  ['brt',
#   'kotakuuk',
#   'elit',
#   'ai',
#   'creat',
#   'super',
#   'weapon',
#   'and',
#   'start',
#   'hunt',
#   'player',
#   'skynet',
#   'is',
#   'here',
#   'httpstcofpskzagnbq',
#   'httpstcoroeoi53eyr'],
#  ['btedismeiamt', 'playoverwatch', 'blizzard', 'pc', 'of', 'cours'],
#  ['bhighli',
#   'recommend',
#   'playoverwatch',
#   'by',
#   'the',
#   'good',
#   'peopl',
#   'of',
#   'blizzard',
#   'if',
#   'you',
#   'like',
#   'ultrafast',
#   'team',
#   'fp',
#   'actionnhttpstcogaiamvapnn'],
#  ['brt',
#   'spacex',
#   'next',
#   'launch',
#   'target',
#   'june',
#   '14',
#   'from',
#   'cape',
#   'canaver',
#   'xe2x80x93',
#   '45',
#   'minut',
#   'launch',
#   'window',
#   'open',
#   'at',
#   '1032am',
#   'et',
#   '232pm',
#   'utc',
#   'httpstcoo8m9bixe2x80xa6'],
#  ['btrippi', 'httpstcodtmd5airiq'],
#  ['bahess247',
#   'recod',
#   'i',
#   'love',
#   'dougla',
#   'adam',
#   'my',
#   'favorit',
#   'spaceship',
#   'ever',
#   'is',
#   'in',
#   'hhgttg'],
#  ['bexactli', 'httpstcocy1abiio42'],
#  ['bgood',
#   'articl',
#   'from',
#   'themotleyfool',
#   'explain',
#   'how',
#   'littl',
#   'incent',
#   'have',
#   'actual',
#   'contribut',
#   'to',
#   'tesla',
#   'fund',
#   'httpstcozfc8di7edx'],
#  ['bswiftonsecur', 'how', 'did', 'you', 'know'],
#  ['bcreat',
#   'a',
#   'neural',
#   'lace',
#   'is',
#   'the',
#   'thing',
#   'that',
#   'realli',
#   'matter',
#   'for',
#   'human',
#   'to',
#   'achiev',
#   'symbiosi',
#   'with',
#   'machin'],
#  ['bjedbrown5', 'renzdimaand', 'goetzman', 'tomstear', 'exactli'],
#  ['brenzdimaand',
#   'tomstear',
#   'it',
#   'is',
#   'simul',
#   'all',
#   'the',
#   'way',
#   'down'],
#  ['bat',
#   'thi',
#   'point',
#   'im',
#   'realli',
#   'run',
#   'out',
#   'of',
#   'crazi',
#   'thing',
#   'to',
#   'say',
#   'ani',
#   'suggestionsnhttpstcodgvjbcszn2'],
#  ['blessteza',
#   'control',
#   'of',
#   'super',
#   'power',
#   'ai',
#   'by',
#   'a',
#   'small',
#   'number',
#   'of',
#   'human',
#   'is',
#   'the',
#   'most',
#   'proxim',
#   'concern'],
#  ['bjust',
#   'heard',
#   'that',
#   'norway',
#   'will',
#   'ban',
#   'new',
#   'sale',
#   'of',
#   'fuel',
#   'car',
#   'in',
#   '2025',
#   'what',
#   'an',
#   'amazingli',
#   'awesom',
#   'countri',
#   'you',
#   'guy',
#   'rock',
#   'httpstcouaxubkdyur'],
#  ['byay', 'babi', 'made', 'it', 'homenhttpstcokyyux9znyd'],
#  ['brt',
#   'spacex',
#   'it',
#   'a',
#   'bird',
#   'it',
#   'a',
#   'plane',
#   'httpstcohdpkxtvlm3'],
#  ['bmattytear',
#   'karaswish',
#   'waltmossberg',
#   'youtub',
#   'autost',
#   'chute',
#   'will',
#   'be',
#   'ad',
#   'soon'],
#  ['brecod',
#   'interview',
#   'with',
#   'karaswish',
#   'and',
#   'waltmossberg',
#   'httpstcobdqq7rrev2',
#   'via',
#   'youtub'],
#  ['bsupercharg',
#   'polici',
#   'explain',
#   'well',
#   'by',
#   'latimesnnhttpstcof0cinmw1yunnwil',
#   'post',
#   'detail',
#   'descript',
#   'soon',
#   'i',
#   'think',
#   'it',
#   'a',
#   'good',
#   'balanc'],
#  ['bgood',
#   'summari',
#   'of',
#   'tesla',
#   'annual',
#   'meet',
#   'by',
#   'katiefehren',
#   'httpstcog3ens77hj7'],
#  ['biwanttobeanurs',
#   'sorri',
#   'to',
#   'hear',
#   'that',
#   'will',
#   'take',
#   'care',
#   'of',
#   'thi',
#   'amp',
#   'investig',
#   'to',
#   'see',
#   'if',
#   'issu',
#   'you',
#   'encount',
#   'are',
#   'system'],
#  ['bso', 'it', 'wa', 'good', 'for', 'you', 'too', 'httpstco9cxo39n1lq'],
#  ['bfast',
#   'replay',
#   'of',
#   'today',
#   'rocket',
#   'land',
#   'on',
#   'spacex',
#   'droneship',
#   'ocislynhttpstcoi0qq2d3bt'],
#  ['bdfjsteve',
#   'veri',
#   'similar',
#   'the',
#   'crush',
#   'core',
#   'in',
#   'the',
#   'falcon',
#   'leg',
#   'is',
#   'reusabl',
#   'after',
#   'soft',
#   'land',
#   'but',
#   'need',
#   'to',
#   'be',
#   'replac',
#   'after',
#   'hard'],
#  ['bcrush',
#   'core',
#   'is',
#   'aluminum',
#   'honeycomb',
#   'for',
#   'energi',
#   'absorpt',
#   'in',
#   'the',
#   'telescop',
#   'actuat',
#   'easi',
#   'to',
#   'replac',
#   'if',
#   'falcon',
#   'make',
#   'it',
#   'back',
#   'to',
#   'port'],
#  ['brocket',
#   'land',
#   'speed',
#   'wa',
#   'close',
#   'to',
#   'design',
#   'max',
#   'amp',
#   'use',
#   'up',
#   'conting',
#   'crush',
#   'core',
#   'henc',
#   'back',
#   'amp',
#   'forth',
#   'motion',
#   'prob',
#   'ok',
#   'but',
#   'some',
#   'risk',
#   'of',
#   'tip'],
#  ['bsatellit', 'deploy', 'to', '91000', 'km', 'apoge', 'all', 'look', 'good'],
#  ['b3', 'min', 'to', 'launch', 'httpstcoi5jnds9mco'],
#  ['bspacex',
#   'there',
#   'wa',
#   'a',
#   'tini',
#   'glitch',
#   'in',
#   'the',
#   'motion',
#   'of',
#   'an',
#   'upper',
#   'stage',
#   'engin',
#   'actuat',
#   'probabl',
#   'not',
#   'a',
#   'flight',
#   'risk',
#   'but',
#   'still',
#   'worth',
#   'investig'],
#  ['brt',
#   'spacex',
#   'weather',
#   '90',
#   'go',
#   'for',
#   '540pm',
#   'et',
#   'launch',
#   'today',
#   'droneship',
#   'land',
#   'challeng',
#   'veri',
#   'hot',
#   'and',
#   'fast',
#   'firststag',
#   'reentri',
#   'httpstcoxe2x80xa6'],
#  ['brt',
#   'openai',
#   'we',
#   'have',
#   'some',
#   'fantast',
#   'new',
#   'team',
#   'member',
#   'httpstcovvphyzz9n',
#   'welcom'],
#  ['brealli',
#   'fun',
#   'model',
#   'x',
#   'review',
#   'by',
#   'motortrend',
#   'best',
#   'part',
#   'is',
#   'x',
#   'race',
#   'while',
#   'tow',
#   'a',
#   'fuel',
#   'sport',
#   'carnhttpstco0kzopoiarx'],
#  ['brt',
#   'nicoleva',
#   'elonmusk',
#   'daughter',
#   'of',
#   'exxon',
#   'scientist',
#   'speaksxe2x80xa6',
#   'httpstcog4f0ifffa7'],
#  ['bschaffffff',
#   'flight',
#   '24',
#   'is',
#   'def',
#   'capabl',
#   'of',
#   'fli',
#   'again',
#   'but',
#   'it',
#   'make',
#   'sens',
#   'to',
#   'appli',
#   'ground',
#   'delta',
#   'qual',
#   'to',
#   'rocket',
#   'w',
#   'toughest',
#   'entri',
#   'condit'],
#  ['bgreat', 'imag', 'of', 'ancient', 'mar', 'httpstcoiy3angxklq'],
#  ['brt',
#   'juanmtrejo',
#   'guy',
#   'whi',
#   'arent',
#   'you',
#   'share',
#   'thi',
#   'it',
#   'awesom',
#   'sauc',
#   'httpstco0ndqpby3r',
#   'teslamotor',
#   'elonmusk'],
#  ['brt',
#   'spacex',
#   'photograph',
#   'unexpectedli',
#   'captur',
#   'falcon',
#   '9',
#   'second',
#   'stage',
#   'burn',
#   'and',
#   'first',
#   'stage',
#   'entri',
#   'httpstcoikvmvon7gf',
#   'zgreth',
#   'httpstcxe2x80xa6'],
#  ['bjlgolson',
#   'no',
#   'prob',
#   'we',
#   'care',
#   'about',
#   'do',
#   'what',
#   'fair',
#   'amp',
#   'just',
#   'dont',
#   'alway',
#   'get',
#   'it',
#   'right',
#   'but',
#   'intent',
#   'is',
#   'alway',
#   'there',
#   'amp',
#   'we',
#   'make',
#   'amend',
#   'when',
#   'wrong'],
#  ['bjlgolson',
#   'per',
#   'the',
#   'letter',
#   'tesla',
#   'paid',
#   '55hr',
#   'for',
#   'addit',
#   'servic',
#   'so',
#   'no'],
#  ['bjlgolson',
#   'ye',
#   'but',
#   'it',
#   'is',
#   'fals',
#   'of',
#   'merc',
#   'news',
#   'to',
#   'say',
#   'that',
#   'tesla',
#   'took',
#   'advantag',
#   'of',
#   'low',
#   'cost',
#   'labor',
#   'we',
#   'paid',
#   '55hr',
#   'that',
#   'is',
#   'unequivoc'],
#  ['bwe',
#   'still',
#   'need',
#   'to',
#   'make',
#   'sure',
#   'that',
#   'the',
#   'injur',
#   'person',
#   'is',
#   'taken',
#   'care',
#   'of',
#   'but',
#   'less',
#   'amp',
#   'less',
#   'of',
#   'the',
#   'merc',
#   'stori',
#   'appear',
#   'to',
#   'be',
#   'true'],
#  ['bmerc',
#   'news',
#   'stori',
#   'about',
#   'tesla',
#   'use',
#   '5hr',
#   'labor',
#   'seem',
#   'to',
#   'be',
#   'miss',
#   'a',
#   'digit',
#   'tesla',
#   'actual',
#   'paid',
#   '55hr',
#   'httpstco2dth0ncdkx'],
#  ['bdrkevinleung',
#   'teslacanada',
#   'total',
#   'agre',
#   'am',
#   'told',
#   'thi',
#   'will',
#   'be',
#   'fix',
#   'by',
#   'thur',
#   'mayb',
#   'fri'],
#  ['bjoshuapint',
#   'juliusvolz',
#   'full',
#   'height',
#   'of',
#   'falcon',
#   '9',
#   'boost',
#   'stage',
#   'on',
#   'leg',
#   'is',
#   '165',
#   'ft'],
#  ['bfalcon',
#   'heavi',
#   'side',
#   'booster',
#   'can',
#   'use',
#   'most',
#   'of',
#   'the',
#   'same',
#   'airfram',
#   'as',
#   'falcon',
#   '9',
#   'but',
#   'center',
#   'core',
#   'need',
#   'to',
#   'be',
#   'buf',
#   'up',
#   'a',
#   'lot',
#   'for',
#   'transfer',
#   'load'],
#  ['brt',
#   'usatoday',
#   'global',
#   'warm',
#   'is',
#   'get',
#   'wors',
#   'with',
#   'record',
#   'temp',
#   'and',
#   'widespread',
#   'coral',
#   'bleach',
#   'httpstcoz4virzwnea',
#   'getti',
#   'httpstcxe2x80xa6'],
#  ['brespons',
#   'to',
#   'a',
#   'mercuri',
#   'news',
#   'articl',
#   'about',
#   'an',
#   'injuri',
#   'on',
#   'our',
#   'premisesnhttpstco3bfgv6hfia'],
#  ['bmargotroosevelt',
#   'onli',
#   'heard',
#   'about',
#   'thi',
#   'today',
#   'sound',
#   'like',
#   'the',
#   'wrong',
#   'thing',
#   'happen',
#   'on',
#   'mani',
#   'level',
#   'will',
#   'investig',
#   'and',
#   'make',
#   'it',
#   'right'],
#  ['bbittdk',
#   'better',
#   'not',
#   'there',
#   'yet',
#   'but',
#   'a',
#   'solut',
#   'is',
#   'like'],
#  ['b4kpixelsyt', 'ye'],
#  ['bmmustap', 'yup'],
#  ['brt',
#   'joshuapint',
#   'juliusvolz',
#   'elonmusk',
#   'total',
#   'i',
#   'did',
#   'thi',
#   'up',
#   'from',
#   'a',
#   'previou',
#   'one',
#   'to',
#   'give',
#   'it',
#   'scale',
#   'httpstcoy6ozsc2std'],
#  ['bmost',
#   'recent',
#   'rocket',
#   'took',
#   'max',
#   'damag',
#   'due',
#   'to',
#   'v',
#   'high',
#   'entri',
#   'veloc',
#   'will',
#   'be',
#   'our',
#   'life',
#   'leader',
#   'for',
#   'ground',
#   'test',
#   'to',
#   'confirm',
#   'other',
#   'are',
#   'good'],
#  ['bthree', 'compani', 'httpstconrffmtpzzw'],
#  ['brspacex',
#   'reddit',
#   'will',
#   'do',
#   'anoth',
#   'ama',
#   'just',
#   'befor',
#   'reflight',
#   'of',
#   'the',
#   'rocket',
#   'in',
#   'a',
#   'few',
#   'month'],
#  ['bdog',
#   'snuggl',
#   'thread',
#   'on',
#   'reddit',
#   'comment',
#   'get',
#   'realli',
#   'good',
#   'httpstco7cc6rnsvsn'],
#  ['bexcit',
#   'to',
#   'announc',
#   'tesla',
#   'entri',
#   'into',
#   'automot',
#   'race',
#   'httpstcopzh1ldxpwl'],
#  ['brt',
#   'jdickerson',
#   'seat',
#   'at',
#   'breakfast',
#   'ha',
#   'made',
#   'me',
#   'a',
#   'tesla',
#   'enthusiast',
#   'report',
#   'base',
#   'on',
#   'tabl',
#   'of',
#   'owner',
#   'next',
#   'to',
#   'me',
#   'the',
#   'joy',
#   'from',
#   'the',
#   'car',
#   'is',
#   'ixe2x80xa6'],
#  ['brt',
#   'teslamotor',
#   'onli',
#   'need',
#   '30',
#   'cm',
#   'to',
#   'spread',
#   'it',
#   'wing',
#   'wherev',
#   'you',
#   'go',
#   'modelx',
#   'httpstco5dxdjw9tg'],
#  ['brt',
#   'teslamotor',
#   'xe2x80x9cmodel',
#   's',
#   'save',
#   'my',
#   'husband',
#   'the',
#   'father',
#   'of',
#   'our',
#   'kidsxe2x80x9d',
#   'michel',
#   'httpstcopfnkej2pkd'],
#  ['brt', 'teslamotor', 'cool', 'view', 'modelx', 'httpstcor5cepohuvh'],
#  ['brt',
#   'stationcdrkelli',
#   'thank',
#   'spacex',
#   'for',
#   'get',
#   'our',
#   'scienc',
#   'safe',
#   'back',
#   'to',
#   'earth',
#   'veri',
#   'import',
#   'research',
#   'httpstcolwkgks5trg'],
#  ['bclubtesla', 'teslamotor', 'tambixc3xa9n', 'te', 'amo'],
#  ['brt',
#   'nashenas88',
#   'teslamotor',
#   'elonmusk',
#   'fantast',
#   'counter',
#   'to',
#   'mislead',
#   'la',
#   'time',
#   'articl',
#   'httpstcot4otnnr8q0',
#   'via',
#   'fredericlambert'],
#  ['biwritethewrong', 'it', 'probabl', 'the', 'ambien'],
#  ['bdefinitelynhttpstco7gekc0mt9o'],
#  ['bok', 'httpstcojjjr28ugrk'],
#  ['bfull',
#   'credit',
#   'to',
#   'the',
#   'team',
#   'that',
#   'do',
#   'thi',
#   'all',
#   'happen',
#   'without',
#   'ani',
#   'help',
#   'from',
#   'me',
#   'httpstcofaze01llea'],
#  ...]

# %%
def idf(vocabulary, documents):
    """TODO: compute IDF, storing values in a dictionary"""
    idf={}
    totaldocument = len(documents)
    for word in vocabulary:
        count = 0
        for doc in documents:
            for i in doc:
                if(word == i):
                    count += 1
        idf[word] = math.log(totaldocument/count)
    ...
    return idf

idf = idf(vocabulary, documents)
[idf[key] for key in vocabulary[:5]]
# Out:
# [1.7599886001766294,
#  2.2846552753544915,
#  2.5369657196539936,
#  2.6018032391493016,
#  2.6162613223245317]

# %%
# def vectorize(documents, vocabulary, idf, tf):
#     document_vectors = [0] * len(documents)
#     for i, document in enumerate(documents):
#         document_vectors[i] = [0] * len(vocabulary)
#         for j, term in enumerate(vocabulary):
#             document_vectors[i][j] = idf[term] * tf[i][j]
#     return document_vectors

def vectorize(document, vocabulary, idf):
    vector = [0]*len(vocabulary)
    counts = Counter(document)
    for i,term in enumerate(vocabulary):
        vector[i] = idf[term] * counts[term]
    return vector

document_vectors = [vectorize(s, vocabulary, idf) for s in documents]
np.array(vocabulary)[np.where(np.array(document_vectors[1]) > 0)], np.array(document_vectors[1])[np.where(np.array(document_vectors[1]) > 0)]
# Out:
# (array(['tesla', 'exactli'], dtype='<U17'), array([2.28465528, 4.61193298]))

# %% [markdown]
# ### 1.3. Compare the results with the reference implementation of scikit-learn library.

# %% [markdown]
# Now we use the scikit-learn library. As you can see that, the way we do text normalization affects the result. Feel free to further improve upon (OPTIONAL), e.g. https://stackoverflow.com/questions/36182502/add-stemming-support-to-countvectorizer-sklearn

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1,1), min_df = 1, stop_words = 'english', max_features=500)

features = tfidf.fit(original_documents)
corpus_tf_idf = tfidf.transform(original_documents) 

sum_words = corpus_tf_idf.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in tfidf.vocabulary_.items()]
print(sorted(words_freq, key = lambda x: x[1], reverse=True)[:5])
print('testla', corpus_tf_idf[1, features.vocabulary_['tesla']])
# Out:
# [('http', 163.54366542841234), ('https', 151.85039944652075), ('rt', 112.61998731390989), ('tesla', 95.96401470715628), ('xe2', 88.20944486346477)]
# testla 0.3495243100660956

# %% [markdown]
# ### 1.4.  Apply TF-IDF for information retrieval
# We can use the vector representation of documents to implement an information retrieval system. We test with the query $Q$ = "tesla nasa"

# %%
from numpy import dot
from numpy.linalg import norm

# cos_sim = dot(a, b)/(norm(a)*norm(b))
def cosine_similarity(v1,v2):
    """TODO: compute cosine similarity"""
    sumxx, sumxy, sumyy = 0, 0, 0
    result = dot(v1, v2)/norm(v1)*norm(v2)
    ...
    return result

def search_vec(query, k, vocabulary, stemmer, document_vectors, original_documents):
    stemmer = PorterStemmer()
    q = query.split()
    q = [stemmer.stem(w) for w in q]
    query_vector = vectorize(q, vocabulary, idf)
    
    # TODO: rank the documents by cosine similarity
    scores = [[cosine_similarity(query_vector, document_vectors[d]), d] for d in range(len(document_vectors))]
    scores.sort(key=lambda x: -x[0])
    
    print('Top-{0} documents'.format(k))
    for i in range(k):
        print(i, original_documents[scores[i][1]])

query = "tesla nasa"
search_vec(query, 5, vocabulary, stemmer, document_vectors, original_documents)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-5c76276a475b> in <module>
#      25
#      26 query = "tesla nasa"
# ---> 27 search_vec(query, 5, vocabulary, stemmer, document_vectors, original_documents)
#
# NameError: name 'stemmer' is not defined

# %% [markdown]
# We can also use the scikit-learn library to do the retrieval.

# %%
new_features = tfidf.transform([query])

cosine_similarities = linear_kernel(new_features, corpus_tf_idf).flatten()
related_docs_indices = cosine_similarities.argsort()[::-1]

topk = 5
print('Top-{0} documents'.format(topk))
for i in range(topk):
    print(i, original_documents[related_docs_indices[i]])
# Out:
# Top-5 documents
# 0 b'@ashwin7002 @NASA @faa @AFPAA We have not ruled that out.'
# 1 b"SpaceX could not do this without NASA. Can't express enough appreciation. https://t.co/uQpI60zAV7"
# 2 b'@NASA launched a rocket into the northern lights http://t.co/tR2cSeMV'
# 3 b'Whatever happens today, we could not have done it without @NASA, but errors are ours alone and me most of all.'
# 4 b'RT @NASA: Updated @SpaceX #Dragon #ISS rendezvous times: NASA TV coverage begins Sunday at 3:30amET: http://t.co/qrm0Dz4jPE. Grapple at  ...'
