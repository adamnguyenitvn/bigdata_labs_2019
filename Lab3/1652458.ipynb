# %% [markdown]
# # Visualization with Matplotlib

# %% [markdown]
# ## Example

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y, 'r')
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title("String Title Here")
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %% [markdown]
# ## Exercises

# %%
import pandas as pd

# %%
df1 = pd.read_csv('city_data.csv')
df2 = pd.read_csv('ride_data.csv')

# %%
df1.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
df2.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %%
result = pd.merge(df1, df2)
result.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
result2 = result.groupby(['city'])['fare'].mean()
result2.head()
# Out:
# city
# Amandaburgh      24.641667
# Barajasview      25.332273
# Barronchester    36.422500
# Bethanyland      32.956111
# Bradshawfurt     40.064000
# Name: fare, dtype: float64

# %%
result3 = result.groupby(['city'])['driver_count'].count()
result3.head()
# Out:
# city
# Amandaburgh      18
# Barajasview      22
# Barronchester    16
# Bethanyland      18
# Bradshawfurt     10
# Name: driver_count, dtype: int64

# %%
result4 = result.groupby(['city'])['ride_id'].count()
result4.head()
# Out:
# city
# Amandaburgh      18
# Barajasview      22
# Barronchester    16
# Bethanyland      18
# Bradshawfurt     10
# Name: ride_id, dtype: int64

# %%
result5 = pd.merge(result2, result3,on=['city'])
result5.head()
# Out:
#                     fare  driver_count
# city
# Amandaburgh    24.641667            18
# Barajasview    25.332273            22
# Barronchester  36.422500            16
# Bethanyland    32.956111            18
# Bradshawfurt   40.064000            10

# %%
result6 = pd.merge(result5, result4,on=['city'])
result6.head()
# Out:
#                     fare  driver_count  ride_id
# city
# Amandaburgh    24.641667            18       18
# Barajasview    25.332273            22       22
# Barronchester  36.422500            16       16
# Bethanyland    32.956111            18       18
# Bradshawfurt   40.064000            10       10

# %%
result6.columns=['Average Fare', 'Number of Drivers', 'Number of Rides']
result6.head()
# Out:
#                Average Fare  Number of Drivers  Number of Rides
# city
# Amandaburgh       24.641667                 18               18
# Barajasview       25.332273                 22               22
# Barronchester     36.422500                 16               16
# Bethanyland       32.956111                 18               18
# Bradshawfurt      40.064000                 10               10

# %%
y = result6['Average Fare'].tolist()

# %%
x = result6['Number of Rides'].tolist()

# %%
import matplotlib.pyplot

# %%
matplotlib.pyplot.scatter(x,y,s= [a**1.7 for a in x],c='yellow',alpha=0.4,edgecolors='black')
plt.grid()
plt.xlabel('# of Rides')
plt.ylabel('Average Fare Per City')
plt.title("Rides vs Fare")
plt.xlim(xmin=0)
plt.show()

# %%
total_fares = result.groupby(['type'])['fare'].sum()
total_fares.head()
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
total_rides = result.groupby(['type'])['ride_id'].count()
total_rides.head()
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
fig, [ax1,ax2] = plt.subplots(1,2)
ax1.pie(total_fares,explode=(0,0,0.1),labels=['Rural','Suburban','Urban'],autopct='%1.1f%%',shadow=True,startangle=60,colors=['#f7d943','#87ceeb','#e8702a'])
ax1.set_title("% of Total Fares")


ax2.pie(total_rides,explode=(0,0,0.1),labels=['Rural','Suburban','Urban'],autopct='%1.1f%%',shadow=True,startangle=60,colors=['#f7d943','#87ceeb','#e8702a'])
ax2.set_title("% of Total Rides")

plt.show()

# %% [markdown]
# # Visualisation with Seaborn

# %% [markdown]
# ## Example

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'])

# %%
sns.pairplot(tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')

# %%
sns.stripplot(x='day',y='total_bill',data=tips)

# %% [markdown]
# ## Exercises

# %%
ds = sns.load_dataset('titanic')
ds.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import pandas as pd

# %%
temp4 = ds.drop(['pclass','sibsp','parch','embarked','class', 'adult_male','deck','embark_town','alive','alone','who','survived','sex','age'],axis=1)
temp4.head()
# Out:
#       fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %%
pd.plotting.scatter_matrix(temp4)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF0B86D860>]],
#       dtype=object)

# %%
sns.set_style("whitegrid")
sns.boxplot(x='class',y='age',data=ds,palette='rainbow')

# %%
temp = pd.concat([ds['age'],ds['sex']],axis=1)
temp.head()
# Out:
#     age     sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
temp2 = temp.groupby(['age'])['age'].count()
temp2.head()
# Out:
# age
# 0.42    1
# 0.67    1
# 0.75    2
# 0.83    2
# 0.92    1
# Name: age, dtype: int64

# %%
sns.pairplot(temp2)

# %%
temp3 = ds.drop(['pclass','sibsp','parch','embarked','class', 'adult_male','deck','embark_town','alive','alone','fare','who'],axis=1)
temp3.head()
# Out:
#    survived     sex   age
# 0         0    male  22.0
# 1         1  female  38.0
# 2         1  female  26.0
# 3         1  female  35.0
# 4         0    male  35.0

# %%
sns.swarmplot(x='sex',y='age',data=temp3,hue='survived',split=True)

# %% [markdown]
# # Dimensionality Reduction

# %% [markdown]
# ## Example

# %%
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.decomposition import PCA as sklearnPCA

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
data = pd.read_csv(url,header=None)

y = data[4]
X = data.iloc[:,0:4]

# %%
data.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
plt.scatter(X[y=='Iris-setosa'].iloc[:,0], X[y=='Iris-setosa'].iloc[:,1],label='Iris-setosa',c='red')
plt.scatter(X[y=='Iris-versicolor'].iloc[:,0], X[y=='Iris-versicolor'].iloc[:,1],label='Iris-versicolor',c='blue')
plt.scatter(X[y=='Iris-virginica'].iloc[:,0], X[y=='Iris-virginica'].iloc[:,1],label='Iris-virginica',c='lightgreen')

plt.legend()
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')

plt.show()

# %%
X_norm = (X - X.min())/(X.max() - X.min())

# %%
plt.scatter(X_norm[y=='Iris-setosa'].iloc[:,0], X_norm[y=='Iris-setosa'].iloc[:,1],label='Iris-setosa',c='red')
plt.scatter(X_norm[y=='Iris-versicolor'].iloc[:,0], X_norm[y=='Iris-versicolor'].iloc[:,1],label='Iris-versicolor',c='blue')
plt.scatter(X_norm[y=='Iris-virginica'].iloc[:,0], X_norm[y=='Iris-virginica'].iloc[:,1],label='Iris-virginica',c='lightgreen')

plt.legend()
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')

plt.show()

# %%
pca = sklearnPCA(n_components=2)
transformed = pd.DataFrame(pca.fit_transform(X_norm))

# %%
plt.scatter(transformed[y=='Iris-setosa'].iloc[:,0], transformed[y=='Iris-setosa'].iloc[:,1],label='Iris-setosa',c='red')
plt.scatter(transformed[y=='Iris-versicolor'].iloc[:,0], transformed[y=='Iris-versicolor'].iloc[:,1],label='Iris-versicolor',c='blue')
plt.scatter(transformed[y=='Iris-virginica'].iloc[:,0], transformed[y=='Iris-virginica'].iloc[:,1],label='Iris-virginica',c='lightgreen')

plt.legend()
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')

plt.show()

# %% [markdown]
# ## Exercises

# %%
ds = pd.read_csv('wine.data.csv')
ds2 = pd.DataFrame(ds['Label'])
ds=ds.drop(['Label'],axis=1)
ds.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# ...

# %%
ds2.head()
# Out:
#    Label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
pd.plotting.scatter_matrix(ds,figsize=(20,20))
plt.show()

# %%
corr = ds.corr()

plt.figure(figsize=(20,20))

sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
           cmap="YlGnBu",
           annot=True)

# %%
from sklearn import preprocessing
standardScaler = preprocessing.StandardScaler()
standardScaler.fit(ds)
X_scaled = standardScaler.transform(ds)
normData = pd.DataFrame(X_scaled,columns = ds.columns)
normData.head()
# Out:
#     Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0  1.518613   -0.562250  0.232053          -1.169593   1.913905
# 1  0.246290   -0.499413 -0.827996          -2.490847   0.018145
# 2  0.196879    0.021231  1.109334          -0.268738   0.088358
# 3  1.691550   -0.346811  0.487926          -0.809251   0.930918
# 4  0.295700    0.227694  1.840403           0.451946   1.281985
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0       0.808997    1.034819             -0.659563         1.224884
# 1       0.568648    0.733629             -0.820719        -0.544721
# 2       0.808997    1.215533             -0.498407         2.135968
# 3       2.491446    1.466525             -0.981875         1.032155
# 4       0.808997    0.663351              0.226796         0.401404
#
#    Color intensity       Hue     OD280   Proline
# 0         0.251717  0.362177  1.847920  1.013009
# 1        -0.293321  0.406051  1.113449  0.965242
# ...

# %%
from sklearn.cluster import KMeans
kMeansClustering = KMeans(n_clusters = 3, random_state=None)
res = kMeansClustering.fit_predict(normData)

# %%
normData['cluster'] = res

# %%
# normData['cluster'] = label_pred_KM.astype('float64')
sns_plot = sns.pairplot(normData,hue="cluster",diag_kind='hist')
